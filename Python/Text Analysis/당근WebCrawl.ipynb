# %% [markdown]
# <a href="https://colab.research.google.com/github/CharmStrange/Project/blob/main/Python/Text%20Analysis/%EB%8B%B9%EA%B7%BCWebCrawl.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install konlpy
# Out:
# Collecting konlpy
#   Downloading konlpy-0.6.0-py2.py3-none-any.whl (19.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.4/19.4 MB 39.2 MB/s eta 0:00:00
# Collecting JPype1>=0.7.0 (from konlpy)
#   Downloading JPype1-1.4.1-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (465 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 465.3/465.3 kB 40.2 MB/s eta 0:00:00
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.10/dist-packages (from konlpy) (4.9.3)
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.10/dist-packages (from konlpy) (1.23.5)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from JPype1>=0.7.0->konlpy) (23.1)
# Installing collected packages: JPype1, konlpy
# Successfully installed JPype1-1.4.1 konlpy-0.6.0

# %%
# 웹 페이지의 URL

서울특별시 = "https://www.daangn.com/region/%EC%84%9C%EC%9A%B8%ED%8A%B9%EB%B3%84%EC%8B%9C"
부산광역시 = "https://www.daangn.com/region/%EB%B6%80%EC%82%B0%EA%B4%91%EC%97%AD%EC%8B%9C"
대구광역시 = "https://www.daangn.com/region/%EB%8C%80%EA%B5%AC%EA%B4%91%EC%97%AD%EC%8B%9C"
인천광역시 = "https://www.daangn.com/region/%EC%9D%B8%EC%B2%9C%EA%B4%91%EC%97%AD%EC%8B%9C"
광주광역시 = "https://www.daangn.com/region/%EA%B4%91%EC%A3%BC%EA%B4%91%EC%97%AD%EC%8B%9C"
대전광역시 = "https://www.daangn.com/region/%EB%8C%80%EC%A0%84%EA%B4%91%EC%97%AD%EC%8B%9C"
울산광역시 = "https://www.daangn.com/region/%EC%9A%B8%EC%82%B0%EA%B4%91%EC%97%AD%EC%8B%9C"
세종특별자치시 = "https://www.daangn.com/region/%EC%84%B8%EC%A2%85%ED%8A%B9%EB%B3%84%EC%9E%90%EC%B9%98%EC%8B%9C"
경기도 = "https://www.daangn.com/region/%EA%B2%BD%EA%B8%B0%EB%8F%84"
강원특별자치도 = "https://www.daangn.com/region/%EA%B0%95%EC%9B%90%ED%8A%B9%EB%B3%84%EC%9E%90%EC%B9%98%EB%8F%84"
충청북도 = "https://www.daangn.com/region/%EC%B6%A9%EC%B2%AD%EB%B6%81%EB%8F%84"
충청남도 = "https://www.daangn.com/region/%EC%B6%A9%EC%B2%AD%EB%82%A8%EB%8F%84"
전라북도 = "https://www.daangn.com/region/%EC%A0%84%EB%9D%BC%EB%B6%81%EB%8F%84"
전라남도 = "https://www.daangn.com/region/%EC%A0%84%EB%9D%BC%EB%82%A8%EB%8F%84"
경상북도 = "https://www.daangn.com/region/%EA%B2%BD%EC%83%81%EB%B6%81%EB%8F%84"
경상남도 = "https://www.daangn.com/region/%EA%B2%BD%EC%83%81%EB%82%A8%EB%8F%84"
제주특별자치도 = "https://www.daangn.com/region/%EC%A0%9C%EC%A3%BC%ED%8A%B9%EB%B3%84%EC%9E%90%EC%B9%98%EB%8F%84"

# %%
import requests
from bs4 import BeautifulSoup

# GET 요청으로 웹 페이지 내용 가져오기
response = requests.get(제주특별자치도)
html_content = response.text

# BeautifulSoup을 사용하여 HTML 파싱
soup = BeautifulSoup(html_content, "html.parser")

# class가 "card-title"인 요소들 찾기
card_title_elements = soup.find_all(class_="card-title")

# 결과 출력 및 저장
output_file = "list.txt"
with open(output_file, "w", encoding="utf-8") as f:
    for element in card_title_elements:
        title = element.get_text(strip=True)
        print(title)
        f.write(title + "\n")

#print(f"총 {len(card_title_elements)}개의 제목을 출력 및 '{output_file}'에 저장했습니다.")
# Out:
# 고사양 게임용 컴퓨터 싸게 팝니다 배그 디아4 상옵가능!!  i5 / 3070급!
# 롯데리아 불고기 버거 세트 기프티콘 팔아요!
# 테르톤 20형 공업용 박스팬 선풍기 (2대 보유)
# 신세계상품권
# 위닉스 공기청정기 팝니다.
# 상태 좋은 매트리스 판매합니다
# 홍콩야자
# 신화월드 빅3 팝니다. 5장 일괄요
# 별표주유소 주유상품권
# 꿀
# 캠핑장비 처분 헬리녹스 스노우피크 침낭 텐트
# 라푸마 등산배낭
# 사각 모듈 선반
# 작업대 팔아요
# 아이폰 14프로 128 퍼플 액정깨짐
# 에어팟 프로
# 레져보트 선박 4.1톤 12인승 팝니다.
# 혼마 경량 캐디백 (남여공용) 골프백
# 올리브영 5만원권 2장있어요~
# 이사정리/2인 쇼파
# 갈치 상품!! 오늘 하루 동안에만 이가격!!
# 아이폰12미니
# 티비 와사비망고 4K UHD LED TV 65인치
# 18만짜리  스탠냄비 팔게여
# 풍년압력솥10인용
# 헬리녹스 택티컬 필드 터널 4.35
# 아이패드 프로 12.9 와이파이 wifi 256기가 (2세대)판매합니다.
# 작업대 팔아요
# LG에어컨
# 책장
# 컴퓨터 본체
# 신화월드 BIG3 3장 팝니다.
# 나인브릿지 주말 총 5장 일괄
# 디퓨져와 크리스마스트리 인테리어용품
# 해표 선물세트 팔아요.
# 리안 드림콧 아기침대
# 전자렌지
# 몽탄 10/3 3시
# 아이폰11프로맥스64g
# 500w 인버터+ 밧데리(자동차용)
# 르샤트라 섬유유연제 팝니다
# 행거및 3단서랍장 팝니다
# 농막 컨테너팝니다
# 샤넬
# 복숭아 나무
# 여성용 골프채 풀세트
# 늙은호박
# 기내용 캐리어 싸게 판매
# 마끼다 슬라이딩 각도 절단기
# 지리산 벌꿀
# 디월트 송풍기 샌딩기 충전기 배터리포함
# 나인브릿지 퍼블릭쿠폰
# 에어포스 된장 265
# 스톤아일랜드 니트카라티 판매합니다
# 구포국수 팔아요
# 업소용다이냉장고
# 냉방기(에어컨실외기)
# 아이폰se1 스그 64G 팝니다.
# 미니 청소기 팝니다~
# 아세아관리기 운반기
# 미니냉장고 전자랜지
# 서랍장 팝니다~
# 아이폰7 팝니다
# 선풍기
# 삼성 게이밍 노트북, GTX1650 외장그래픽 모델
# 에어팟 프로2 본체 풀박스 (S급)
# 제습기
# 가죽소파 이사땜에 팝니다
# 낚시대 팔아요
# 커피
# 235여성구두
# 신형 클리블랜드 웨지
# 테이블
# 새상품 브랜드 런닝화(2켤래 4만원)
# 스탠드 행거
# 콜로비아등산가방
# 신세계상품권 지류 팝니다.
# 삼도 사우나 티켓 팔아요.~~
# 우유냉장고
# 에어팟프로 1 a급
# 냉장식품 삼진어묵 2종
# 빛의벙커 초대권 4장 일괄 (~10/15)
# 삼성 노트북 팝니드
# 유아신발 130,135,140
# 냉난방기45평형 판매합니다
# 만화책 모노노케 히메 전권
# 건조기 팔아요
# 에어프라이어 자취 필수템
# 운동화250밀리
# TBJ  가을남방 자켓 S사이즈
# 슈퍼싱글 침대 세트
# 도서문화 상품권 판매
# 일렉기타 2016 깁슨 레스폴 트레디셔널
# 골프세트 팝니다
# 피칸 반태1kg
# 깔끔한 까사미아 시스템장 판매
# 노리풀 오늘 10.2일 10시 양도

# %%
from konlpy.tag import Okt
from collections import Counter

# 저장된 제목을 불러오기
input_file = "list.txt"
with open(input_file, "r", encoding="utf-8") as f:
    titles = f.readlines()

# 형태소 분석기 초기화
okt = Okt()

# 모든 제목에서 명사 추출
nouns = []
for title in titles:
    nouns.extend(okt.nouns(title))

# 가장 많이 나온 상위 명사 10개 추출
top_nouns = Counter(nouns).most_common(10)

# 결과 출력
print("가장 많이 사용된 명사:")
for noun, count in top_nouns:
    print(f"{noun}: {count}회")
# Out:
# 가장 많이 사용된 명사:
# 판매: 7회
# 프로: 6회
# 세트: 5회
# 장: 5회
# 아이폰: 5회
# 상품권: 4회
# 급: 3회
# 일괄: 3회
# 에어팟: 3회
# 미니: 3회

# %%
import requests
from bs4 import BeautifulSoup

# 변수들을 딕셔너리에 저장
regions = {
    "서울특별시": "https://www.daangn.com/region/%EC%84%9C%EC%9A%B8%ED%8A%B9%EB%B3%84%EC%8B%9C",
    "부산광역시": "https://www.daangn.com/region/%EB%B6%80%EC%82%B0%EA%B4%91%EC%97%AD%EC%8B%9C",
    "대구광역시": "https://www.daangn.com/region/%EB%8C%80%EA%B5%AC%EA%B4%91%EC%97%AD%EC%8B%9C",
    "인천광역시": "https://www.daangn.com/region/%EC%9D%B8%EC%B2%9C%EA%B4%91%EC%97%AD%EC%8B%9C",
    "광주광역시": "https://www.daangn.com/region/%EA%B4%91%EC%A3%BC%EA%B4%91%EC%97%AD%EC%8B%9C",
    "대전광역시": "https://www.daangn.com/region/%EB%8C%80%EC%A0%84%EA%B4%91%EC%97%AD%EC%8B%9C",
    "울산광역시": "https://www.daangn.com/region/%EC%9A%B8%EC%82%B0%EA%B4%91%EC%97%AD%EC%8B%9C",
    "세종특별자치시": "https://www.daangn.com/region/%EC%84%B8%EC%A2%85%ED%8A%B9%EB%B3%84%EC%9E%90%EC%B9%98%EC%8B%9C",
    "경기도": "https://www.daangn.com/region/%EA%B2%BD%EA%B8%B0%EB%8F%84",
    "강원특별자치도": "https://www.daangn.com/region/%EA%B0%95%EC%9B%90%ED%8A%B9%EB%B3%84%EC%9E%90%EC%B9%98%EB%8F%84",
    "충청북도": "https://www.daangn.com/region/%EC%B6%A9%EC%B2%AD%EB%B6%81%EB%8F%84",
    "충청남도": "https://www.daangn.com/region/%EC%B6%A9%EC%B2%AD%EB%82%A8%EB%8F%84",
    "전라북도": "https://www.daangn.com/region/%EC%A0%84%EB%9D%BC%EB%B6%81%EB%8F%84",
    "전라남도": "https://www.daangn.com/region/%EC%A0%84%EB%9D%BC%EB%82%A8%EB%8F%84",
    "경상북도": "https://www.daangn.com/region/%EA%B2%BD%EC%83%81%EB%B6%81%EB%8F%84",
    "경상남도": "https://www.daangn.com/region/%EA%B2%BD%EC%83%81%EB%82%A8%EB%8F%84",
    "제주특별자치도": "https://www.daangn.com/region/%EC%A0%9C%EC%A3%BC%ED%8A%B9%EB%B3%84%EC%9E%90%EC%B9%98%EB%8F%84"
}

# 반복문을 통한 웹 크롤링 및 결과 저장
for region, url in regions.items():
    response = requests.get(url)
    html_content = response.text
    soup = BeautifulSoup(html_content, "html.parser")
    card_title_elements = soup.find_all(class_="card-title")
    output_file = f"list_{region}.txt"

    with open(output_file, "w", encoding="utf-8") as f:
        for element in card_title_elements:
            title = element.get_text(strip=True)
            print(title)
            f.write(title + "\n")
# Out:
# 아디다스 삼바
# 신세계상품권100만원 80만원에 팝니다
# 아이폰14프로 팔아요
# 미니냉장고
# 아디다스 삼바
# 미니 냉장고
# [미사용 새제품] 설화수 화장품 5종 세트
# 신세계 이마트 상품권10만원4장 35만원판매
# 위닉스 뽀송제습기 10L 팝니다.
# LG 냉장고
# 앤틱시계
# 하만카돈 사운드스틱1
# 폴로 여아 가디건 2T
# 스팸세트 5호
# 또❗️업데이트‼️)투쿨포 새상품 4000원🤭
# 다이슨 청소기 싸게 가져가세요!
# 오늘 산 베이글
# 딤채김치냉장고 330L
# 레이디가구 이안 빅 슬라이딩 옷장 1200 행거형
# 셀린느 퀴르 버킷
# 아이패드 프로 12.9 5세대 + 애플펜슬 2세대 + 매직키보드 판매합니다
# 고추가루 2023년
# 발뮤다공기청정기
# 샤넬 스니커즈 37
# 사우스케이프 s 여성
# 루펜 음식물처리기
# 오프화이트 테이프 내로우 후드티 S
# 선물세트
# 아람 자연이랑 전집
# sk주유권 15000원 싸게팝니다
# la갈비선물세트
# 에어팟프로 맥세이프 지원 모델
# 추석선물세트 cj스페셜g호
# 발렌시아가원통백
# 가방 1
# 오스프리 50리터 배낭
# 버버리 10y - 간절기 경량 패딩
# 갤럭시 노트s8
# 내친구수학공룡
# 수납장
# 스팸, 카놀라유 몽땅
# 이케아 철제선반
# 삼성tv 정리합니다.
# 리바이스 501(32) 새상품
# 코베아큐브난로
# 신세계상품권 30만원
# 베트남 동 판매합니다.
# matin kim 마뗑킴 봄버 자켓 블랙 스티치자켓 블랙
# 키즈풀빌라 양도 ㅠㅠ 오늘입니다ㅠㅠ
# 벽걸이 장식 티스푼
# 사고 그대로 있는 신발
# 철재 선반겸 책장
# 아이폰 충전선 어댑터. 모두 일괄판매
# 베네베네 상하의세트 (12-18m)
# 구찌. 스몰 백 새재품
# 휘슬러  솔라  냄비
# 컴퓨터 본체 + 모니터 팝니다
# 샤넬 니트
# 파타고니아 토렌셸 3L
# 코스트코 1년회원권
# 노스페이스 눕시 다운 베스트
# 샤X 카드지갑
# 폴로 랄프로렌 여성니트 xs(55-66)
# 라코스테 여자 가디건 미국 s 5천원
# COS(코스) 오버사이즈 백
# 롯데백화점 10만원 상품권
# 새상품 나이키 남성 기능성자켓
# 아이폰11 퍼플 128G
# 아이폰 11 퍼플
# 정품정리
# 로렉스 서브마린 청콤 10년정도...생활기스 있습니다~
# 필리핀 페소 팝니다(7,357페소)
# 거위털 경량패딩 골프잠바 골프옷
# 에르메스 클릭아슈 블랙 골드 pm
# 서랍장
# 서울랜드 종일권 팝니다
# 새 수건
# 폴로 옥스포드셔츠 2벌
# 루디변색고글
# 보조배터리, 무선이어폰
# 전동킥보드
# 침대 월요일에 가져가야합니다
# 플라스틱 서랍장
# Pc본체
# 프라다남자패딩자켓
# 스투시벨트
# 코스트코 회원권 연간
# 베트남 동 팝니다
# 이케아 6단 서랍
# NIKE 나이키 정품 남성스윔팬츠
# 타이틀리스트 남자 점퍼 110
# 헬리녹스 체어원 탄색 볼핏포함
# 3단 철제 선반
# 홀리데이 타프 판매합니다
# 156L 냉장고 싸게 팔아요
# 베트남동 + 동지갑 팝니다.
# 엘지트윈스 유광점퍼
# 삼성냉장고
# 다이슨공기청정기
# 미우미우(정품) 급처분
# 상품권 신세계 10만원, 롯데 10만원 두장 팝니다~
# 컴퓨터 판매(본체+모니터)
# 추피생활이야기
# 아이폰13프로
# 고성 한산마리나 리조트 숙소 오늘당일 (10월2일~3일) 1박2일 숙박권
# 미드센츄리 테이블 판매합니다!
# 스팀 청소기
# 갤럭시 노트 8
# 삼성전자 세라믹 전자레인지 블랙 버튼식 23L
# 지샥 지얄오크
# 정품 K2패딩 점퍼 헝가리구스 필파워800
# 레이디 핑크백
# 로얄베이비 스페이스셔틀 18인치 어린이자전거
# 리바이스 흑청자켓 XL(105)
# 전자렌지 넘겨요
# 전자레인지 팝니다
# 키친아트 커피포트 새거 팔아요~
# jbl 펄스2 블루투스 스피커
# 아이스크림 카트
# 루이비통캐리어
# 신세계 상품권 10만원 3장
# 샤넬향수
# 완
# 몽클레어 구스 패딩
# 샤넬가방 정품
# 전자렌지.렌지대.침대
# 버버리 정품 목도리 일괄 판매
# 밀워키임팩
# 아이폰xs max 골드 256G 판매
# 클라윈드 올화이트 냉장고
# 롯데 상품권 10만원
# 내친구과학공룡 판매해요
# 물냉면
# 로토토베베 조끼 다람이, 베어 M사이즈 (쌍둥이추천)
# 아이폰12미니 128기가  팝니다
# 라코스테 가디건 판매
# 빌라쥬드  아난티 듀플렉스
# 스벅 기프트카드 5만원권 한장더생겼오용
# 대저캠핑장 오늘 10/2 1박
# 노스페이스운동화겸트레킹화270사이즈
# 빈폴 u-slim남성바지 90 블랙 2장가격
# 롯데시네마 영화관람권 9/30까지
# 야마토야식탁의자
# 갤럭시워치 6 클래식 47mm 팔아요
# 여성로렉스금통급처분
# 갤럭시노트20울트라
# lg인버터 전자렌지
# 이지부스트 버터 싸게팔아요
# 스톤 마이크로랩스 바람막이 판매
# 밀폐용기 세트
# 스탠리 텀블러 새상품
# 식용유~
# 동원선물세트 프리미엄
# 메디큐브 에어샷
# 페소팝니다.
# LG통돌이세탁기
# 버버리 스카프
# 후라이팬.고구마판.전골냄비그릇등
# 경주 힐튼 호텔 (한글날, 조식미포함)
# 애플워치7 41mm 스타라이트 GPS
# 부산pcx125 21년식
# 스팸 6호
# 신세계 상품권 10,000원
# 18만짜리  스탠냄비 팔게여
# 32인치 티비겸 모니터
# 엄청 큰 캐리어 팝니다
# 상품권
# 메디큐브 에이지알 EMS
# 메밀국수/씨간장
# 휘슬러 냄비
# 샤넬 가브리엘 백팩 스몰 내장칩 새제품(가격내림)
# 광안리불꽃축제숙박권
# 정품 구찌목걸이
# 시계 새상품
# 파타고니아 후리스 베스트 XL
# [미사용 새제품]레디우스 퍼터 33.75인치 일자형
# 자라 와이드 팬츠
# 밀워키 대포 송풍기
# 나이키 빅스우시 바람막이
# 몽클레어 니트자켓 L
# 스피드랙 행거
# 낚시 장비 싸게 팝니다
# 소르니아 아기 옷장
# 참치,고추참치
# 밀폐 용기 세트
# 생
# 타요 미끄럼틀 안전한 버전 (상태 좋아요)
# 유팡 LED 젖병소독기 (세턴화이트)
# 낚시경단 감성돔경단
# 스팸햄 팝니다.
# (정품)클라터뮤젠
# 에어팟 프로1
# 불발) 배 선물세트 8과
# 청도캠프안단테 오토캠핑장 1박(10.2) 양도
# 배 선물세트 판매합니다
# 분쇄기
# 철제선반
# trek 자전거
# 삼성스탠드 김치냉장고
# 해운대호텔숙박권판매
# 스토케 트립트랩
# 태블릿 갤럭시 a8
# 인터불고 뷔페 상품권 판매
# 순수원목 행거 선반 세트
# Lg청소기
# 동원 참치서물세트
# 신세계 상품권 10만원
# 20인지24인지 컴퓨터 모니터 판매
# 나이키 한벌105호
# 한샘 샘키즈 수납장, 책장 팔아요.
# 한성 모니터 24인치 ultron 2457 ultra ips패널
# 라꾸라꾸온열침대팝니다.
# 스투시 롱슬리브
# 전자랜지
# 스마트라이크 트램폴린
# 불고기버거 기프티콘팔아요
# 커플링
# 박카스
# 전기자전거
# 스페셜라이즈드 24인치 자전거
# 김일권꿀벌
# 밤꿀
# 아이폰 12pro 다 깨짐
# 1인 리클라이너(수동)
# 18k반지 루이비통 판매합니다
# (정품)피엘라벤 세트
# 18k반지 까르띠에 판매합니다
# 신세계 상품권 50만원
# 왕자 행거
# 아이폰6 팝니다 배터리상태91퍼
# 신세계 쿠폰 50000원 티켓 2장 팔아용
# 추피책  팔아요
# 남자 나이키 운동화
# 엘지 드럼 세탁기  9키로
# 하이브리드 자전거
# 18k 팔찌
# 스팸 복합 5호
# 질스튜어트 가방
# 히니크 긴팔 니트 (아이보리, free)
# 아이폰14프로맥스 퍼플
# 군용침낭팝니다~
# 신세계백화점 상품권 11만원 팝니다.
# 루이비통숄더백
# 한번써보고는 사용하지않아서요
# 선반판매합니다
# 삼성라이온즈 포토카드 팝니다
# 삼성라이온즈 시즌 프리권 3장 판매합니다
# 꼼데가르송 가디건 M 블랙로고
# 청도 글램핑 숙박권
# 샤넬 헤어미스트
# 삼성라이온즈 유니폼 110
# 들기름
# 스팸 복합 S호 팝니다.
# 이케아 둑티그 주방놀이
# 애플워치 시리즈4 나이키 에디션 44mm 셀룰러
# 자전거 공기주입기 팝니다(joeblow)
# 인텔 4세대 i7 4790 h81m 16g 메인보드 셋트 판매합니다
# 삼성라이온즈 신정환선수 에버랜드 유니폼
# LG오브제 컬렉션 냉장고 팔아요~~~
# 철봉
# 베베드피노 뽀글이 우주복 85
# 티비장 거실장 티비다이
# 라디오
# 1200*700*720 화이트 빅 테이블 책상
# 연락 주세요
# 신세계상품권 10만원권 판매
# 전자레인지
# 플립4 256기가 블루 sk정상해지 공기계 선택약정가능
# 세수비누
# ck87황축 키보드 한성게이밍모니터{모니터는 판매완료) 판매합니다
# 산리오 시나모롤 다합해서 5천원!!!!
# 아이폰 XS 64GB 팝니다.
# 삼성 핸드청소기
# 아이폰 13pro 256g sss실버
# 업소용
# 디올 리비에라 에코백
# 샤넬 트렌디CC 클래식 미니
# 혈압계
# 천장형선풍기.캠핑
# (한글날연휴) 꿈애오토캠핑장 캠핑장 양도합니다
# 땡큐휴지30롤
# 세수비누
# 자전거
# 예초기 작동잘됩니다
# 65인치 tv 팔아요
# 돈 급해서 싸게팔아요 ㅜㅠ
# 디올 크로스백
# 무슨 용도인지 정확하게 모르겠어요ㅠ
# 선물세트팔아요
# 43인치 티비 DH4302UB
# 스팸6호
# 버즈 프로 팔아요
# 중고 데스크탑 판매
# 노부영 베스트
# LG 전자레인지 팝니다.
# 가정용 인바디 체중계
# 양파
# [팝니다] 꼼데가르송 긴팔 블랙 가디건 (100)
# 주유권
# 보증 남은 s21 울트라 싸게 판매
# 다이슨 에어랩
# 컴퓨터급처분합니다
# 금강제화
# 서울우유 판매합니당
# 아이폰11프로맥스 64기가 팝니다
# 가방
# 카놀라유, 요리유,양조간장(새상품)
# 냄비셋트가격
# 컴퓨터 본체
# 등산스틱
# 마르디 메크르디 니트
# 가방
# 무조건 ❤1000원❤️<여성 상의 모음>
# 구찌 새상품
# 갤럭시 노트20  싸게팔아요~
# 필요하신분
# 해피콜 냄비셋트 가격
# 테팔 후라이팬 4종세트
# 다양한 책 팔아요
# 가방
# 24k
# 나이키230.퓨마230.텐디250.등산화230
# 뉴발란스 2002 그레이 260 팝니다
# 식탁.긴의자
# 남자 블루종 가죽자켓
# 신세계 백화점 상품권
# 도레미곰 45권+ 증강본8권(cd,송북포함)
# 궁 쇠고기 육포 480g
# 맘스보드 칠판+동물퍼즐자석+과일자석+알파벳,한글 자음모음자석
# 갤럭시 버즈2 프로 화이트 판매합니다
# 베이비뵨 매쉬 바운서
# i7 3770 16gb gtx660 ssd120gb 사무용 본체
# 엔진11 크릿디 건메탈 2022 픽시 급처or대차합니다!!
# 아이폰 11 프로 256, 93%
# 본체
# 24K 금팔찌 팝니다.
# 고투 자충매트더블
# 냉장고 싸게 가저가세요
# 에어프라이기팝니다
# 이불차렵세트 팔아용
# 전통시장 및 상섬가 온누리 상품권
# 노트20울트라
# 가방포함릴선. 리드선. 릴케이블 판매합니다.
# 신세계상품권3만원 판매합니다~~~~
# 컴퓨터 본체 팝니다
# 스팸 클래식 8호 새상품
# 비비안웨스트우드 아리엘라 목걸리 급처!
# uhd티비65인치,스마트기능
# 3단.4단 선반
# 스토케 트립트랩
# 차량용청소기겸용입니다
# 플스5디지털에디션
# PVC용접기
# 18만짜리 스탠냄비 팔게여
# 🖤옷장정리 해요🤍
# 삼성 김연아 에어컨
# 식용유
# 아디다스 져지 두벌
# 사용하지를 않습니다
# 이케아 대나무 트레이
# 새제품-USB 지원 비지니스 백팩, 노트북 배낭 ,다목적 배낭
# 디올 새들 카드지갑 판매합니다
# 가방
# 로엠 블라우스(새상품)
# 국산 고추가루
# 에어팟 프로 2세대
# 보조배터리
# 베트남 돈  480만동  팜
# 젤네일
# 쇼케이스 냉장고팝니다
# 사물함
# 아이폰 8+ 256GB
# 사물함
# 숲소리악기세트
# 자라 스트럭처 니트 재킷
# 이층침대
# 쏠비치 진도 10월8일 입실 1박  양도
# 동원참치s12호
# 에어팟 프로 1세대
# 하늘도담쌀 5키로
# 철재서랍(일괄)
# 신세계 상품권 50만원
# 흰색선반
# 에시앙 범보의자 컨디션좋음
# 갤럭시워치4 44mm
# 골프
# 4단 선반 판매
# 디올 레이디백
# 삼성 49인치 UHD 4K TV
# 낚시 릴세트 및 용품
# 네셔널지오그래픽M,L 세트 팔아요~
# OLED TV 65인치(번인있음)
# 비타파워 필요하신분(200병중 마지막20병 남았습니다)
# 해표 선물세트팝니다
# 아이폰13pro 128기가 실버 팔아요
# 코웨이제습기
# 배
# 컴퓨터 팝니다
# 롯데상품권 판매 합니다
# 신세계 상품권 5만원 팝니다
# 위니아냉장고 판매합니다
# 아이폰 11 128g 팝니다
# 프롬유샤워핸들
# 콜롬비아 네이비 경량패딩
# 갤럭시 s23 256기가 블랙
# 뭐하는건지는뭐르지만팔아요
# 밧드 일괄
# 이태리14k 남자팔찌 20m 이뽀요 ^^
# 미싱
# 롯데상품권 10만원짜리 두장
# 버버리 니트(새상품)
# 디월트dcd706(거의새거)
# 골프 풀셋 정리합니다
# 식용유
# 구호 스트링 롱 트랜치
# 마이크로킥보드 맥시 레드
# 갤럭시z폴드4 256기가화이트
# 리바트 옷장 시스템장 판매합니다.
# 석류나무
# 애플워치se2 40mm팝니다
# 갤럭시워치3 ,45mm 블루투스
# 시계
# tv
# 위닉스 제습기
# 동원참치선물세트 10호
# 스파게티 파스타 소스
# 알집매트 팔아요
# 아이폰 12 128 팔아요
# 갤럭시 워치3 클랴식
# 순천만국제정원박람회 티켓 4장
# 아이나비 QXD7000 블랙박스
# 에어팟프로 유닛
# 할리데이비슨 스포스터s 21년식
# 이거팝니다
# 고추가루
# 후드집업 팔아용
# 김치냉장고
# 아이두젠 3-4인용 원터치텐트 판매 합니다.
# 야구글러브일괄판매
# 명절전 판매합니다🫶
# 참기름
# 선풍기
# 그루비 반주기
# 혼주 세트
# 디스커버리모자
# 두번사용했습니다
# 꼼데가르송 가디건
# 갤럭시탭s7 128기가 셀룰러
# 화이트숏패딩
# cbr 125
# 프뢰벨 영아다중 팝니다.
# 컴퓨터 파라요
# 엘지전자렌지
# Keenz 웨건
# 아기신발 새신발
# 참치세트
# 루이비통 루프백 판매 (가격내림)
# 발렌티노 클러치백
# 삼양라면
# 갤럭시 RTX 2060 화이트 박스 포함 최상급
# 아이패드 미니
# 조각칼
# 버버리 가방(이제 안나옴)(찔러보기 답장안함)
# 콜롬비아 정품 여성95  바람막이 새상품이에요
# 조명 팝니다
# 테이블 의자
# 몽클레어 가을용 바람막이팝니다.
# 햄팔아요:)
# 아시아나 비행기 프라모델 a350 a350-900
# 리챔12호
# 롯지 무쇠 그릴팬 27cm
# 맨유 98-99 블록코어룩 패션 유니폼
# 최근까지 잘 탔던 자전거 그냥 싸게 팔아요
# TV 팝니다.
# 밤고구마 10kg
# 크롬하츠 팔찌 팝니다.
# LG디오스 양문 냉장고 판매합니다
# rtx 2060 그래픽카드 판매
# 신세계 상품권 5만원권 팝니다
# 소베맘 기저귀갈이대
# 윌슨 테니스공 소포니
# 칼세트
# 에어팟 프로 A2084
# 일본 가시는분
# 알렉산더 맥퀸
# 다이슨공기청정기
# 아이폰xs 64기가 실버 판매합니다 !
# 로봇청소기
# LG55인치 TV(해외직구) 판매합니다.
# 네이버페이 92퍼 판매합니다
# 투미 알파 콤팩트 백팩
# 캠핑 화롯대
# 애플펜슬 2세대
# 아이폰11
# 노트북 삼성 센스 i5
# 급처 아이폰12 미니 64gb 배터리효율 75%
# 신세계 상품권
# 나이키  조거팬츠
# 샤넬cc로고 벨크로 샌들
# 야외용 나무 원목 테이블 의자 테라스
# 인텔 i7 게이밍 컴퓨터(pc, 데스크탑, 본체) 롤 서든 디아 스타 옵치 피파 배그
# 베지밀 검은콩 아몬드호두 두유
# 노스페이스자켓
# 금호리조트 숙박권 팝니다
# 대용량몬스터2리터믹서기
# 갤럭시노트10+
# 루이비통 네버풀 다미에 MM
# 1-2회착용한 바버 시리즈 간절기 상의 판매합니다
# 베베드피노
# 포카리스웨트 340ml x 20병 2박스
# 디올 등 향수 3가지
# 쇼파용 온열매트 새상품
# 윤석열 대통령 시계 팝니다.
# 아이폰11프로그린 64gb
# 삼성 에어컨
# 제이앤제나 역방쿠
# 애플워치4 40mm 셀룰러모델
# 타이니모빌
# 쿠첸 6인용 압력 밥솥
# 나이키 크로스백. 낭여공용
# 마크바이마크제이콥스 자동우산
# 독일산 파쉬 찜질팩 새제품
# 콜맨 트레일헤드2 야전침대
# 해먹
# 코베아 캠핑의자
# 신세계 백화점 5만원 상품권
# 콜라 판매합니다
# 7500F / 4070 / 32GB / 2TB 올게임 풀옵션 게이밍 컴퓨터 본체
# 갤럭시 S23 울트라 팬텀블랙 512gb (자급제) 팝니다
# 아이패드 프로3세대 11인치 64g wifi
# 2 대
# 삼성 갤럭시 Z플립3 크림색
# 아이폰12미니 화이트 128g 판매합니다.
# 제습기
# 자전거
# 아이폰12미니 급쳐합니다
# 아기 범퍼 침대 겸용 매트
# 동원 참치 20캔
# 씨투엠뉴 에이블 유모카
# 나이키 바람막이 세트
# 아이패드 프로 11 3세대
# 아기 버버리패딩 18m
# 갤럭시노트9
# 루이비통 가방
# 실내자전거
# 신세계상품권
# 42인치 LG TV 팝니다
# 삼성 복합기 5만원에 급처분 / 인터넷에 25만원에 판매중
# 2인용 식탁의자 판매합니다
# Nike 나이키 ACG 써마핏 플리스 기모 후디 후드티 블랙 DH3088-010
# HG 프반 풀아머건담 팝니다
# 골드바 1냥
# 캘러웨이 여성 골프웨어 가디건
# 삼성 40  인치  티비
# 벽난로장 판매합니다.
# 4단 선반
# 싱글침대
# 캔버스 토트백
# 웰크리 5종세트
# 빈스메시프 침낭
# [샤넬 코스메틱] 샤넬 컬렉션 한정 하이라이터 까멜리아 드 플룸
# 참치캔 사세요
# 타이틀리스트 벨트
# 추피시리즈
# 현대백화점 10만원 상품권 팝니다[9만원]
# 갤s22팝니다
# 파키라 식물
# 스팸8호 팔아요
# 갤럭시 버즈프로2 팝니다.
# 왕큰 참치캔 20캔 세트😙😋
# 윤석열 대통령기념시계
# 울산현대 이청용
# 아이폰12미니  128 팔아요
# 폴로 니트쪼끼 팝니다
# 접시 일괄
# 알밤 팔아요~
# 샤인머스켓 싸게 드립니다.
# 2구가스렌지
# 기타 판매
# 스팸등등
# 코스트코  고릴라랙  6칸
# 아이패드 5세대 급처 합니다 !
# 한샘 샘키즈 수납장 팝니다
# 빽다방 기프티콘 팔아용
# 철재 베란다테이블
# 5단 틈새 수납장
# 배 선물세트
# 스카티 카메론  퍼터
# 폴로반팔니트
# 스톤아일랜드(바람막이)
# 몇번 안쓴 대용량 샴푸 린스
# 전자레인지
# 산리오 정품 인형 일괄 판매
# 스톤아일랜드 바람막이
# 전기자전거 판매합니다
# 에스오일 상품권 팝니다
# 스팸8호선물세트
# 시계
# 220v -> 110v 변압기
# 테팔 코팅깨끗.짱짱한 후라이팬
# 스팸100호
# 블랙 박스
# 울산현대 유니폼 oem
# 가격제안해주세요!
# 달러팝니다 140불
# 고추바사삭 안먹어서 팔아요..15000
# 버즈2프로 유닛
# ☆☆☆5800x + 32gb ram 팝니다☆☆☆
# LG 2in1 에어컨
# 블랙가방
# 에어팟 프로 2세대
# 원형러그팝니다
# 의성 햇 고추가루
# 엠프키타
# 커세어 키보드
# 배달의 민족 상품권
# 빈티지 수납장
# 진공쌀통
# 나이키 더플백 판매
# 뉴발란스 패딩 판매
# 갤럭시 s22울트라 판매합니다
# 방갈로
# 리바이스청바지 정품
# 게임용 컴퓨터 세트(모니터 키보드 마우스 헤드셋 스피커 포함)
# 18k 목걸이 길이 40~44까지
# 면도기
# 메이커 옷들 싸게 판매합니당🩶
# 냉장고
# 카드지갑
# 백팩 팝니다. (뉴발란스, 포니)
# 삼성 2in1 에어컨
# 맥세이프 차량용 충전기
# 프로스펙스 운동화 265
# 삼성 15.6인치 i7 쿼드코어 속도빠른 노트북 팔아요
# 폴드3  512 기가팝니다
# 한성32인치 모니터
# 나이키 티셔츠
# 코코 수납형 원목 화장대
# LED 데스크 램프 스텐드
# 마제스티7 블루투스스피커 판7만
# 아이폰 13 128GB
# 몇번 안쓴 선실크샴푸 밀크바오밥 화이트머스크 트리트먼트
# 카본 로드자전거
# 갤럭시 s22울트라 판매합니다
# 화이트나이트건조기
# 나이키 세트
# 아디다스 저지 팔아요
# 캠핑용아이스박스
# 핑크맨투맨
# 구찌 반지갑 판매합니다
# 캠핑의자
# 삼성스마트TV 벽걸이 포함
# 아이폰 13pro max
# 책
# 에어팟 프로 1 팝니다(급처)
# 롯데 신세계 상품권
# 꼼데 가디건
# 린나이 가스렌지(도시가스용 LNG)
# 수저세트
# LG제습기
# 조이 아이스핀 360 카시트(검정)
# 식용유 카놀라유
# 에어팟 프로 2
# 스텐 3단 스텐 찜기
# 대만달러
# 타요 주차타워
# 업글하고 나옴) 2년전 고스펙으로 맞췄던 컴퓨터 팝니다.
# 쌤키즈 수납장
# 락앤락 도시락통
# 앵글선반판매합니다
# 타요 세이프티 버스
# 팸퍼스 기저귀 6-7단계(15kg~) 베이비드라이 120매
# 전신거울
# 옛날집 고재  목재 기둥(폭 10,길이 200)
# 헤지스, 폴로, 코오롱
# 책장 2단 3단
# 아이폰 SE1 스그 64GB
# 아빠차트
# 급하게 처분합니다
# 블랙 카페 125 클래식바이크
# 오메가 씨마스터 쿼츠
# 암웨이치약
# 갤럭시 S9+
# 베이비올 수과학
# 매직캔 휴지통
# 나이키 백팩
# 설민석의 한국사 대모험,디즈니 세계문화,탈무드,앗시리즈,경제동화,전래동화,리더쉽동화,코딩책,한국역사,성경동화,영어책
# DKNY 니트
# 판매합니다
# 튤립 사운드북 새상품
# 뽀로로코딩컴퓨터
# 프렌치캣 패딩 120
# 바디앤솔 필라테스 양도
# 와이드핏 바지
# 쿠킹호일,비닐팩
# 메디큐브에이지유세라딥샵
# 나이키 테크팩 조거팬츠
# 아이폰 12 128G 블랙
# 밀패용기
# 나이키 반팔
# 유팡젖평소독기
# 아기 코스튬 아기 도날드 아기할로윈
# 신세계 상품권 5만원
# (새상품)샤넬 에코 미디움 토트백 블랙/화이트
# 일룸옷장
# 스팸 12호 선물세트
# 장인한과 장인약과 파지약과
# 나무도마  새거와  스텐 과일바구니
# 폴로(Ralph Lauren)  베스트 조끼 M size
# 나이키 드라이핏 후드집업 XL
# 배 배선물 과일선물
# 한샘 싱글 침대
# 아이폰 13 미니
# 추피 세이펜 버전
# 골프하프백
# 락앤락 쌀냉장고 새제품 싸게 팝니다.
# 믹서 분쇄기
# new 다이슨 에어랩 롱 컴플리트 리퍼(새상품x, 재당근)
# 스팸 현명한선택 105호, 스팸6호 각 3만원, 일괄 구매 시 5만원
# 화이트 선반 팝니다
# (새상품) 5 in 1, 아이패드 노트북 탭 태블릿 받침대, 거치대, 독서대,
# 이케아 테이블
# 애플 아이맥 24인치
# 뉴발란스.USA.270mm
# 이케아 스트란드몬 1인용소파
# 아스파라거스 나누스 화분째 팔아요
# 정관장 활기력 20ml 16병
# 코스 퀼팅백 미니 블랙
# 버버리 정품(스카프)
# 나이키 에어맥스 265mm
# 스팸 선물세트 판매합니다.
# 트렌치코트
# (그릇) 빌레로이앤보흐 디자인나이프 7P + 코렐 4P
# 다이슨 V10 앱솔루트 엑스트라 및 거치대랑 추가툴
# 100 사이즈 정도  폴로 아프리콧 등
# 100 여름 양복 자켓 2벌
# 갤럭시 울트라20 , 256g
# 전자레인지
# 아디다스 져지 블랙
# 전기그릴팝니다
# 세라젬 웰카페 음료&체험쿠폰(20장)
# 옛날지폐
# 아이폰8 (배터리 고장) 64G
# 압소바 긴팔 우주복 세트(75, 6m) 새상품
# 분리수거 수납함
# 나이키 조던 정품 275
# 유시몰 칫솔
# (새제품) Lee 모자
# 스와로브스키 목걸이 판매합니다(당근 최저가)
# 스와들업 s 오리지널(세탁만 한 새상품)
# 버버리긴팔티.M
# 사랑초(예약중). 히메 몬스테라 식물
# 갤럭시 노트20 note20 kt정상해지 특A급 팝니다.(256g)
# 스팸8호 팝니다
# 아이폰 11 화이트 64GB
# 꿀고구마 한입고구마
# 22년도쌀20kg
# 추피 빚글 동화책
# 보은 알밤~사이즈 보셔요ㅎ(판매완료)
# 엘지냉동고
# 송편
# 참치 선물셋트 2셋 일괄3만원에 팔아요
# 국산미 20kg
# 베베드피노 바람막이 팝니다
# 삼성 TV 50인치
# 와이업 휴대용 유모차
# 루이비통 카드지갑 팝니다
# 무선카플레이 10인치 1달사용
# 신일 무선청소기
# (미사용 새제품) 갤럭시워치6 47mm 실버 새제품 +정품스트랩 +정품거치대+강화유리+링케이스
# 스팸 카놀라유 올리고당 선물세트
# 골프빽 스탠드형
# 싱거미싱 1408
# 온열매트. 134×47
# 자석블럭(에드토이) 팝니다
# 테일러메이드 M6 드라이버 10.5도
# 신세계상품권 10만원
# 아이폰 14프로맥스
# 마이크로킥보드 맥시(LED 됨)
# 에어팟 3세대 팝니다
# 베트남동 팝니다 807000동
# 나이키 골프가방과 골프체
# 카드지갑(새상품)
# 삼성 인버터 17.2L 제습기
# 에어팟 프로2 S급 팝니다.
# 디월트 30L 업소청소기
# 싱크대
# 젝시오 여성 드라이버 (1회사용)
# 아이폰14pro 256 스페이스블랙
# 크록스 240 w7 팝니다.
# 신세계 상품권
# 나이키 코리아 정품 에어맥스 270사이즈 팝니다
# 고구마 캐가실 분
# 갤럭시s21핸드폰 팝니다
# LA갈비 3키로 저렴하게 판매 합니다
# 신세계 이마트 상품권 2장
# 겔럭시 S10 5G 256G 팝니다
# 숲소리 원목블럭 66P
# 노스페이스 외투 정리합니다.
# 몽클레어 가디건
# 나이키 에어맥스270
# 캠핑용야전침대
# 삼성에어컨 10만에 드려요
# LG노트북 (LG15U34) + 가방포함
# 식품건조기
# 온수매트 싱글
# 에버랜드 자유이용권
# 매장 집기/잡다한 것들 판매 합니다. 많은 문의 주세요.
# 미니로디니 9298 외 티셔츠 4종 일괄
# 낚시대
# Z플립3
# 노스페이스 히말라야 M사이즈 판매합니다
# 미니 수건
# 스마트폰 노트10+ 256G
# 핸펀 워치
# 해바라기버너
# 스팸8호
# WD 외장하드 4테라
# 베네베네 롬퍼 12m
# 노트 10+
# 고야드 가방
# 크레마사운드업 이북리더
# 아이폰 13 스타라이트
# 스투시 베이직 기모맨투맨 네이비L 새상품
# 냉장고 팔아요
# 신세계  상품권
# 갤럭시 핏2 스마트워치 팝니다
# 아이폰 6s 로즈골드
# 메종키츠네 가디건 판매
# 제트플립 1세대 판매합니다
# 아이폰11 화이트 64기가 (액정파손)
# 신일서큘레이터
# 수납장
# 선물용 과일
# 스팸선물셋트
# 아이폰 12미니 화이트 256gb 판매합니다.
# 주중숙박  가평
# 마이크로트라이크
# 무쇠솥
# 배 15kg 1박스 상태신선
# 아이폰 11프로 급처
# 베이트릴  낚시릴 장구통릴
# 티파니앤코 리턴투
# 이케아 철제 선반
# 기내용 캐리어 팝니다
# 새수건 일괄판매
# 참치.햄
# 깨끗한 캠핑테이블
# 클레식기타
# 참치선물세트
# 전남친이 사준거라 팔아요
# 가격내림680000
# 삼성 노트북
# 에어팟 프로2(급처)
# 밤 팝니다.
# 스팸
# 캠핑첨낭
# 전자렌지 넘겨요
# 철원오대쌀 10kg  기준 입니다
# 스팸
# 휴지
# 갤럭시노트20
# 어항 (+물고기, 조명)
# 후아유 양털 후드집업
# 페소팝니다
# 카놀라유
# 냉동고50L
# 말본 남성 골프 바지+모자 새제품(32)
# 샤브샤브 놋그릇
# 햅쌀
# 접이식 화로대 미니
# 갤럭시 s10 5g 256기가 판매
# 난로
# 자연관찰책 보드북 세이펜가능
# 더블하트 젖꼭지LL 와이드전용
# 라코스테 니트티
# 무선청소기
# 춘천 빅힐모텔 오늘 숙박
# 컨테이너 하우스
# 볼빅 모자
# 식용유
# 루이비통 크로스백 팔아요
# MCM 가방
# 고구마판매
# 보스 스피커
# 닭모이쌀
# 상태 최상 위니아 208리터 냉장고
# 캠핑용난로
# 모니터 겸 TV
# 하동가 곰탕
# 아이폰 6 판매합니다!!
# 신세계 이마트 지류 상품권 2만원권 판매
# [ 정품 ] 구찌 소호가죽 디스코백
# 현관.도어록
# 화분 팝니다
# 경운기타이어 새거
# 아이엠마더 1단계 800g 팔아요
# 집안에 쓰던 화목난로
# 순순덩어리한냥
# 구찌 가방 판매합니다 (정가 295만원)
# 월광보합 게임기
# 6인용 식탁과 의자
# LG WING
# 블루래빗 아기책 전권
# 14k 목걸이
# 자연진리 명작 배 8구 세트
# 탁상드릴
# 상품권
# 보스턴백
# 놋그릇
# 러닝리소스 텃밭
# 텀블러 미사용 새상품
# 크록스 새거
# 소장 휴대용 게임기들 처분해봅니다
# LG 퓨리케어 몽블랑 공기청정기 as121vas
# 힐티 충전드릴 콤보
# 삼지닥나무(나무.꽃)
# 책상 + 의자
# 차량광택기
# 지프 카고바지
# 골프백 커버 팝니다.
# 청호나이스 쾌변 비데 S급판매
# 폴로키즈 가디건
# 엘파마 맥스 30단 에어샥 27.5인치 mtb 자전거
# 윤석열 대통령 시계 (남성용)
# 아디다스 풋살화 270(265)
# 라운드 북선반
# 청정원  올리유 NH1호
# 스팸세트 33호
# 캐리어 화물용 28인치 미사용
# 일리 Y3.3 커피머신 & 커피캡슐 판매
# 동원참치
# 향수 하나당 10000원
# 좆되는 전동킥보드
# 애플망고치즈설빙
# 타이니러브모빌
# 겔럭시 z플립3 판매합니다.
# 금메달  2.5돈
# 보쉬그라인더 판매합니다
# 💢루이비통 모노그램 트리오 메신져백 급처~💢(상태 A+급)
# 스매쉬 전동드릴
# 쿠쿠 전기밥솥 입니다
# 맨투맨/후드티 팔아용
# 레고벌크 18kg
# 믹서기 싸게 처분합니다!
# 대용량 캐리어팔아요
# 75인치 티비 판매
# 백설 요리유&참기름 팔아요
# 스벅.파바 기프티콘 판매합니다.
# 에어팟2세대
# 4인 식탁팔아요
# 갤럭시 탭s7 fe wifi 64gv
# 신세계 상품권 20만원 일괄판매
# 소파2 테이블 셋트
# 가히 멀티밤
# 야전침낭
# 리바트 슬라이딩 책장
# 에어팟 프로 1
# 카페 라스파지알레 커피머신 & 그라인더
# 베트남동
# 원목 수납장 팝니다.
# 베이프 후드집업
# 아이폰 12프로 256기가 골드 팝니다
# PP로프 5mm-90M, 6mm-120M, 8mm-150M
# 나이키 운동화 240
# 스팸8호 선물세트
# 다용도 폼 매트 패턴
# k2 슬링백
# 동원 요리유&참기름 팝니다
# 골프가방새거
# 타이니모빌 팝니다.
# 아이패드
# 자이언트 자전거 판매
# 롤렉스
# 사과 배 선물셋트
# 하기스 맥스드라이 3단계(밴드형)
# 3단 수납 선반 판매
# 오프오프스튜디오 스판 트윌 팬츠 그레이 스몰
# 수저세트 팔아요
# 공구
# 레모나 70포
# 박시백의 조선왕조실록 전권 팔아요 가지러오셔야해요
# 라그렌 캔우드 IGT 캠핑 롤케이블 세트(라그렌 플레이트버너)
# 도요토미 반사식 난로 실내용/캠핑용 팔아요
# 아이폰13미니 스타라이트 자급제 256 A급 팝니다
# 선반헹거팝니다
# 가전제품 판매합니다.
# 캠핑용전기선
# 기타
# 유리창 시트지
# 캠핑 화목난로
# 구찌 크로스백
# 락앤락 진공쌀통
# 소파
# 에어팟 프로 1세대 팝니다
# 책상
# 동원참치
# 갤럭시워치4 44mm
# 남자 깔깔이(105size)
# 원목 곡목 체어 팝니다
# 전둥킥보드 팝니다
# 뽀글이  패딩점퍼
# 미니 항아리 새상품
# 쿠쿠 10인용밥솥
# 모던 에디션 기프트 세트 - 샴푸 선물세트
# 아이폰 12미니 팔아요 ~
# 접이식 세탁기
# 수저 세트 팔아요
# 벨라 아기침대
# 쌍케리어
# 100달러 팝니다
# 겔럭시탭
# 동원 참치
# 티비다이
# 파이프 중고자재
# 신세계 상품권 20만원
# 구글 크롬캐스트 4K
# 샤넬 미니하트백 새상품 더스트구성
# 아이폰14프로맥스 퍼플
# 아이폰14 프로 부품용 외관멀쩡
# gs주유소 1만원 두장 !! (얼른 쓸 사람만 사가세용)
# 코멧 참나무 장작 20kg 팝니다.
# 위닉스 제습기
# 전기 케이블 릴선(리드선) 팝니다.
# 짐카트
# 전자레인지
# 관리기
# 선물세트 사과
# 그리들
# 불가리 목걸이 새상품
# 42인치 Lg tv
# 2만원짜리스벅
# 밍크슬리퍼 핑크,블랙 235 새상품
# 생리대 모두 단돈 5천원
# 스팸마일드 8호
# 새것과 다름 없는 삼성 전자렌지 정리(사진5장)
# 전동킥보드 팝니다
# 메트로시티 남자 가죽장갑
# 갤럭시 퀀텀2  판매해요
# (픽시) 룩 464 팝니다
# 아이팟 터치2
# 베네베네 디딤대 3단
# 올리브유 백설
# 아이폰se2
# 책상 의자 세트
# 롯데상품권 판매
# 우쿠렐레
# 타이니모빌
# 아이패드 11인치 케이스+블루투스 키보드
# 상품권
# 향나무 가져가실 분
# LG전자렌지 팝니다
# 업소용 에어컨 판매
# 햅쌀 10키로 4포 팝니다.
# 햅쌀10kg
# 카라반 팔아요
# 식용유,참기름 팔아요
# 몽클레어 여성잠바입니다
# 미니 당구대
# 하우스파이프
# 스팸 판매
# 접시세트
# 삼성 공기청정기+필터리필 팝니다
# 젝시믹스 조거
# 스팸 12
# 푸쉬카
# 듀얼센스 팝니다.
# 들통
# 92.000 신세계
# 제노아 예초기
# 일월 전기매트 슈퍼싱글
# 타이니러브  모빌 흑백홀더+컬러홀더
# 아이폰 12 미니
# 징크판넬
# 발바사지기 팔아요
# 자석 달린 LED 램프 팔아요!♡
# 롯데상품권  26만원
# 운동기구
# 꼬꼬맘12000 깜짝볼10000 일괄20000
# 통돌이세탁기16kg
# 아이폰14프로 128GB 실버 자급제 판매합니다.
# 크린백
# 꿈비 리코코 클린롤매트 프리미엄 양면 252x200x4
# 신세계상품권(20만원)
# 램프쿡 자동회전 냄비
# 기타 받침대
# 샴푸
# 관종후드 사이즈M (기모)
# 13900ks 4090 현재 끝판왕 컴퓨터 판매합니다.
# 탁자 파라솔
# 고가구
# 아이폰 13pro 256기가
# 샤넬부츠 새상품 240
# 전기장판
# 컴퓨터 의자
# 나무선반
# 폴로 니트 신세계백화점구매
# 세탁기, 건조기, 거치대 판매
# 의자 싸게 팝니다
# 베베드피노(100)
# 프라다 실버 체인백 미니
# 무우솎음
# 루비이통 페이보릿 가방팔아요
# 제닉스 게이밍 체어 PC방 의자 중역의자
# 극세사이불/슈퍼싱글
# 가마솥 솥단지
# 리바트 식탁판매합니다
# 아디다스 져지 청색 팔아요
# 신세계 상품권 8만원 판매합니다.
# 55인치 티비 2번 쓴거 팔아요 2만원~
# 실내자전거
# 갤럭시 탭 S6 Lite 64GB
# 벨 냉장고
# 타이니모빌
# 이케아 선반
# 오프화이트 후드집업 급처합니다
# 노트북 팔어요
# 작은냉장고
# 쿠쿠 압력밥솥
# TV
# 옷장 침대 서랍장  화장대
# 노트20 Ultra SSS급
# 코오롱 안전화
# 동원참치 프리미엄 10호
# 화이트의자
# 미니골드 14k 반지
# A4용지 4권(2000매)
# 긴테이블
# 급처 원가 5만 소프시스 코너선반 화이트 디자인
# PS5 디스크에디션 팝니다
# 롤렉스 서브마리너 금통
# 25만원에 구매한 수납장
# 프라다 정품지갑
# 삼성 휴대폰 갤럭시 퀀텀2  팝니다.
# 신세계백화점 상품권판매합니다.
# 컴터싸게팝니다 gtx1060
# 해바라기씨유
# 냉장고
# 장구
# 향수 사실분 네고 가능
# 급처 한샘 북선반 10단 원가 9만 5천
# asus gtx1650 super 팝니다
# 선물용 배(10수)
# 가디건(105)
# 콜라팔아요
# 트랙터 35마력
# 서랍형 사이드 침대협탁 상태매우좋음
# 캉골 미니백
# 차량 휴대용 공기 압축기 입니다..
# 구찌이미가방
# 폴로니트
# 4단 캠핑 우드쉘프행어
# 스투시 정품 후드티 L 정가 20만원
# 30만원대 주고 구매한 테이블 의자 싸게 넘겨요
# 테일러메이드 골프가방 캐디백
# 주방수납장
# 인력거 (자전거)
# 타이틀리스트 기능성 패딩 팝니다
# 데상트 맨투맨
# 자전거 급매❗️
# 트랙터35마력
# 여수숙소(10/1-10/2)
# 양념5종세트
# 전동킥보드 내용필독
# 빈티지 티테이블
# 와이퍼
# Apple Watch 3
# 갤럭시s21+
# 이케아 4단선반
# 화분다이
# 사각 물탱크
# 폴로 카라티
# 나이키 골프화
# 머리핀 일괄
# Sk매직 가스렌지 2구
# 선물세트
# 나이키 정품 맨투맨
# 사발면
# 옴니 직구 난로 팝니다
# 미쏘 패딩자켓
# 엘지 울트라 노트북 판매요
# 꼼데가디건(남녀공용)
# 행거 팝니다
# 성인용텐트
# 어스본 사운드북
# 갤럭시 워치5케이스
# 2톤 마이티 저상
# 밤줍기 합니다.
# 정원박람회시민권
# 고장난예초기
# 스팸 복합100호
# 갤럭시 노트20
# 고압세척기
# 이마트 상품권 1만원->7500원
# 텐트.트윈 가스버너
# 순천 정원박람회 팔아요
# 옛날재봉틀
# 온더바디 세트 팝니다(바디로션 워시세트)
# 주방수전
# 분무기(농업용)
# 스팸복합1호
# 나이키 조거팬츠 s
# 설곤약
# 노트북
# 햇님토이 베이비룸 14p
# 스팸200그람
# 돌김(한박스)
# 아팔란치아 MTB 24단 자전거
# 신세계상품권
# 3단서랍장
# 나이키 L
# 정원박람회
# 3인용 쇼파 팝니다
# 판넬
# 아이폰12 128 판매합니다
# 순천만 국가정원박람회 티켓
# 시멘트일괄
# 경동 기름 보일러
# 교동 선지해장국4 버섯들깨탕2
# 롯데상품권 20만원
# 친환경아이생각수성페인트무광4L
# 아이폰 7
# 오큘러스 퀘스트2 64g 팝니다
# 식이섬유가 포함된 프락토올리고당 판매
# 네스프레소 커피머신
# 아이폰13프로맥스 블랙 256G S급
# 모로칸오일
# 항아리
# 철제 벙커침대
# 방탄소년단 DVD 팝니다.
# 그리스로마신화1-20권(구버전)
# s21
# 캠핑선반 접이식 4단
# 에르메스 운동화 풀박
# 아이폰14프로 배터리100%
# 가방구경하세용~~
# 삼성 TV
# 홈짐 세트 팝니다. 별도판매 가능(중량봉, 원판, 케이블, 벤치, 매트, 거울, 덤벨 등)
# 롯데상품권 판매
# 롯데 상품권
# 초록마을  참기름, 들기름,  깨
# 콜라 판매합니다!
# 버버리정품 클래식코트
# 삼성 모니터 27인치 fhd
# LG 휘센 2in1 에어컨 판매합니다
# 캐리어
# 아이폰x 팝니다
# 정원박람회 티켓입니다.
# 자전거
# 동원선물세트
# 고어텍스 패딩 95(100 가능)
# 버버리 신발팔아요
# LG 오븐(전자레인지 가능)
# 아이폰12Pro(256G, 실버)
# 22년식크루심300알파 팝니다
# 갤럭시s23 플러스
# 비젼냄비 팔아요.
# 엔진톱입니다
# 2단 선반 팔아요~
# 모카골드 마일드 판매합니다.
# 02굴삭기, 트렉터 판매합니다
# 이케아 아기의자
# 철재5단
# 미락 진공쌀통 20kg 판매합니다.
# 커피묶음
# 신세계상품권팝니다
# 게이밍 컴퓨터 라이젠 5600x, 3060, 모니터 포함 판매합니다
# 사조 참치 일괄 (새상품)
# 에펠 진공포장기
# 쿠첸 6인용 밥솥
# 옛날카세트테이프
# 4단선반
# 진공청소기
# 화로대 판매합니다.
# 10돈 돈당31.5 팝니다
# 설록차선물셋트
# 책상
# 태블릿
# 메이드복 팝니다
# 장독
# 샤넬 가브리엘 백팩
# 갤럭시 노트10 플러스 아우라 화이트 256G
# 스투시 다이스 키링 주사위 키링
# 샤넬 가브리엘 백팩
# 애플 에어팟 프로1세대 오른쪽 유닛 판매합니다
# 스팸 200g 10캔
# 참기름
# 하나도 안썼습니다
# 목공용품 디월트클램프 마끼다
# 스팸 팔아요
# 국산 들기름
# 차렵이불~~~
# 스펨선물세트8호
# 선물세트 팔아요
# 롯데상품권 2500만원
# 신일진공청소기
# BMW X5 푸쉬카 판매합니다
# 정말 깨끗한 드론 팔아요
# 모름
# 엔밀리밀리 아기 병풍
# 크레모아 팬 c800 ( 캠핑 선풍기, 서큘레이터)
# 200달러 판매합니다.(1360)
# 아이폰11프로 64
# 타이니모빌 메도우버전 흑백컬러모빌 거치대 어댑터 포함
# 베베드피노 바지 3종 새옷
# 에어팟 맥스
# 식용유
# 2단 서랍 팔아요
# 유아자동차 아기자동차 벤츠자동차
# 흙표 온돌흙침대 싱글사이즈
# 에어팟 2세대
# 소파4인용
# 필요 없어서 판매합니다
# 콘테이너 2.4×2.3'4
# 팝콘기계
# 카멜 상하 듀얼 모니터암 팝니다
# 선풍기(유니맥스)
# 롯데상품권 10만
# 짐보리맥포머스
# 에어팟 프로 판매
# 뉴발란스530SG
# 갤럭시탭 10.4인치 sm-t536 팝니다 개당 가격입니다
# 갤럴시 노트20 울트라 팝니다
# 새상품 250사이즈 부츠
# 뉴발 530
# 버섯 이름
# 차량용냉장고
# 버버리백 진품
# 전자렌지 만원에 팝니다
# 플라스틱의자
# 스팸12호
# 골프채# 핑 G410 아이언 풀셋
# 장흥동산 표고버섯
# 갤럭시 s21
# 디스커버리가방
# 엔씨(NC) 어센틱 유니폼 팝니다.
# 식초참기름
# 고성공룡엑스포 티켓
# 공룡엑스포 티켓
# 아기세탁기
# 참기름
# 갤럭시 Z플립3 256GB 퍼플 저렴하게팜
# 삼성 노트북
# 선풍기3대
# 신세계 상품권
# 멸치팔아요~
# 롯데백화점 상품권 13만원
# 둘 문어 1kg
# 참치선물세트
# 칫솔
# 42인치엘지티비
# 레고 사람
# 셀린느 백
# 풋고추
# 손목시계
# 신세계백화점 상품권
# 빨래바구니 2단
# 고성 공룡엑스포 입장권
# 고성 공룡엑스포 사전예매권 팝니다.
# 제습기
# 겔럭시텝 s7+ 256GB
# 티포트
# 매트로 시티 가방
# 추석선물
# 스팸복합1호 팝니다
# 참기름~
# 삼성a32 팝니다
# 위니아제습기팔아요!
# 10.3일-4일 펜션양도합니다.
# 자전거 팝니다
# 롯데 상품권
# 접이식 미니화로 팝니다
# 18K 도금 대나무 목걸이 판매합니다
# 검은콩 고칼슘두유 ~
# 베이스 기타
# ○  리어카 °  손수레  ●  구르마 ㅁ□
# 블루투스이어폰 LG 판매합니다.
# IH 압력밥솥
# 면장갑
# 아이폰 6s
# 황제침향단
# 폴로 남성 점퍼
# 앵글 선반
# 내셔널지오그래픽 바람막이 자켓
# 컴퓨터 노트북 책상과의자
# 갤럭시23울트라 512
# 아람 도토리인성동화 60권 +6권
# 난로 판매합니다
# 갤럭시워치4 골프에디션
# 원목선반
# 갤럭시 휴대폰
# 아이폰13프로맥스
# 3단 양념통정리대
# 아이스박스
# 핑 패딩조끼
# 원터치 이동식 선반
# 낚시용품 봉돌 팝니다
# 보쉬 원형톱
# 갤럭시23울트라 512
# 엘지 디오스 양문형 냉장고
# PXG투어 캐디백
# 테팔 믹스기
# 디올 향수 미니어처
# 책장정리 전집당 만원(일괄 5만)
# msi rtx 2070 아머
# 그릴
# 양반들기름김
# 새상품] 나이키 정품(3종류)
# 이케아 암체어
# 유아 웨건
# 아식스 운동  바지  입니다
# 홍삼 선물세트
# 샤인4kg
# 에어컨
# 아이폰
# iPhone 13 Pro
# 몽블랑 벨트 새제품
# 고사양 게임용 컴퓨터 싸게 팝니다 배그 디아4 상옵가능!!  i5 / 3070급!
# 롯데리아 불고기 버거 세트 기프티콘 팔아요!
# 테르톤 20형 공업용 박스팬 선풍기 (2대 보유)
# 신세계상품권
# 위닉스 공기청정기 팝니다.
# 상태 좋은 매트리스 판매합니다
# 홍콩야자
# 신화월드 빅3 팝니다. 5장 일괄요
# 별표주유소 주유상품권
# 꿀
# 캠핑장비 처분 헬리녹스 스노우피크 침낭 텐트
# 라푸마 등산배낭
# 사각 모듈 선반
# 작업대 팔아요
# 아이폰 14프로 128 퍼플 액정깨짐
# 에어팟 프로
# 레져보트 선박 4.1톤 12인승 팝니다.
# 혼마 경량 캐디백 (남여공용) 골프백
# 올리브영 5만원권 2장있어요~
# 이사정리/2인 쇼파
# 갈치 상품!! 오늘 하루 동안에만 이가격!!
# 아이폰12미니
# 티비 와사비망고 4K UHD LED TV 65인치
# 18만짜리  스탠냄비 팔게여
# 풍년압력솥10인용
# 헬리녹스 택티컬 필드 터널 4.35
# 아이패드 프로 12.9 와이파이 wifi 256기가 (2세대)판매합니다.
# 작업대 팔아요
# LG에어컨
# 책장
# 컴퓨터 본체
# 신화월드 BIG3 3장 팝니다.
# 나인브릿지 주말 총 5장 일괄
# 디퓨져와 크리스마스트리 인테리어용품
# 해표 선물세트 팔아요.
# 리안 드림콧 아기침대
# 전자렌지
# 몽탄 10/3 3시
# 아이폰11프로맥스64g
# 500w 인버터+ 밧데리(자동차용)
# 르샤트라 섬유유연제 팝니다
# 행거및 3단서랍장 팝니다
# 농막 컨테너팝니다
# 샤넬
# 복숭아 나무
# 여성용 골프채 풀세트
# 늙은호박
# 기내용 캐리어 싸게 판매
# 마끼다 슬라이딩 각도 절단기
# 지리산 벌꿀
# 디월트 송풍기 샌딩기 충전기 배터리포함
# 나인브릿지 퍼블릭쿠폰
# 에어포스 된장 265
# 스톤아일랜드 니트카라티 판매합니다
# 구포국수 팔아요
# 업소용다이냉장고
# 냉방기(에어컨실외기)
# 아이폰se1 스그 64G 팝니다.
# 미니 청소기 팝니다~
# 아세아관리기 운반기
# 미니냉장고 전자랜지
# 서랍장 팝니다~
# 아이폰7 팝니다
# 선풍기
# 삼성 게이밍 노트북, GTX1650 외장그래픽 모델
# 에어팟 프로2 본체 풀박스 (S급)
# 제습기
# 가죽소파 이사땜에 팝니다
# 낚시대 팔아요
# 커피
# 235여성구두
# 신형 클리블랜드 웨지
# 테이블
# 새상품 브랜드 런닝화(2켤래 4만원)
# 스탠드 행거
# 콜로비아등산가방
# 신세계상품권 지류 팝니다.
# 삼도 사우나 티켓 팔아요.~~
# 우유냉장고
# 에어팟프로 1 a급
# 냉장식품 삼진어묵 2종
# 빛의벙커 초대권 4장 일괄 (~10/15)
# 삼성 노트북 팝니드
# 유아신발 130,135,140
# 냉난방기45평형 판매합니다
# 만화책 모노노케 히메 전권
# 건조기 팔아요
# 에어프라이어 자취 필수템
# 운동화250밀리
# TBJ  가을남방 자켓 S사이즈
# 슈퍼싱글 침대 세트
# 도서문화 상품권 판매
# 일렉기타 2016 깁슨 레스폴 트레디셔널
# 골프세트 팝니다
# 피칸 반태1kg
# 깔끔한 까사미아 시스템장 판매
# 노리풀 오늘 10.2일 10시 양도

# %%
from konlpy.tag import Okt
from collections import Counter

# 저장된 제목 파일 목록
region_files = [f"list_{region}.txt" for region in regions.keys()]

# 형태소 분석기 초기화
okt = Okt()

# 모든 제목에서 명사 추출
all_nouns = []

for region_file in region_files:
    with open(region_file, "r", encoding="utf-8") as f:
        titles = f.readlines()

    region_nouns = []

    for title in titles:
        region_nouns.extend(okt.nouns(title))

    all_nouns.extend(region_nouns)

# 불용어 설정
stop_words = ['판매', '기', '용', '인치', '상품', '갤럭시', '삼성', '프로', '미니', '세트', '세대', '단', '정리', '정품', '사이즈', '애플', '블랙', '화이트', '일괄', '급', '급처', '제품', '나이키', '신세계', '선물', '울트라', '아기', '밍', '게이', '맥스', '호']

# 불용어 제외하고 명사 카운트
filtered_nouns = [noun for noun in all_nouns if noun not in stop_words]
top_nouns = Counter(filtered_nouns).most_common(10)

# 결과 출력
print("가장 많이 사용된 명사:\n")
for noun, count in top_nouns:
    print(f"{noun}: {count}회")
# Out:
# 가장 많이 사용된 명사:
#
# 아이폰: 64회
# 상품권: 60회
# 스팸: 32회
# 선반: 28회
# 가방: 24회
# 냉장고: 23회
# 에어팟: 22회
# 의자: 20회
# 컴퓨터: 19회
# 참치: 18회
