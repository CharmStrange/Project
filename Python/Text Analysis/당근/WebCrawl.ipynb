# %% [markdown]
# <a href="https://colab.research.google.com/github/CharmStrange/Project/blob/main/Python/Text%20Analysis/%EB%8B%B9%EA%B7%BC/WebCrawl.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install konlpy
# Out:
# Collecting konlpy
#   Downloading konlpy-0.6.0-py2.py3-none-any.whl (19.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.4/19.4 MB 63.3 MB/s eta 0:00:00
# Collecting JPype1>=0.7.0 (from konlpy)
#   Downloading JPype1-1.4.1-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (465 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 465.3/465.3 kB 33.9 MB/s eta 0:00:00
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.10/dist-packages (from konlpy) (4.9.3)
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.10/dist-packages (from konlpy) (1.23.5)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from JPype1>=0.7.0->konlpy) (23.1)
# Installing collected packages: JPype1, konlpy
# Successfully installed JPype1-1.4.1 konlpy-0.6.0

# %%
# 웹 페이지의 URL

서울특별시 = "https://www.daangn.com/region/%EC%84%9C%EC%9A%B8%ED%8A%B9%EB%B3%84%EC%8B%9C"
부산광역시 = "https://www.daangn.com/region/%EB%B6%80%EC%82%B0%EA%B4%91%EC%97%AD%EC%8B%9C"
대구광역시 = "https://www.daangn.com/region/%EB%8C%80%EA%B5%AC%EA%B4%91%EC%97%AD%EC%8B%9C"
인천광역시 = "https://www.daangn.com/region/%EC%9D%B8%EC%B2%9C%EA%B4%91%EC%97%AD%EC%8B%9C"
광주광역시 = "https://www.daangn.com/region/%EA%B4%91%EC%A3%BC%EA%B4%91%EC%97%AD%EC%8B%9C"
대전광역시 = "https://www.daangn.com/region/%EB%8C%80%EC%A0%84%EA%B4%91%EC%97%AD%EC%8B%9C"
울산광역시 = "https://www.daangn.com/region/%EC%9A%B8%EC%82%B0%EA%B4%91%EC%97%AD%EC%8B%9C"
세종특별자치시 = "https://www.daangn.com/region/%EC%84%B8%EC%A2%85%ED%8A%B9%EB%B3%84%EC%9E%90%EC%B9%98%EC%8B%9C"
경기도 = "https://www.daangn.com/region/%EA%B2%BD%EA%B8%B0%EB%8F%84"
강원특별자치도 = "https://www.daangn.com/region/%EA%B0%95%EC%9B%90%ED%8A%B9%EB%B3%84%EC%9E%90%EC%B9%98%EB%8F%84"
충청북도 = "https://www.daangn.com/region/%EC%B6%A9%EC%B2%AD%EB%B6%81%EB%8F%84"
충청남도 = "https://www.daangn.com/region/%EC%B6%A9%EC%B2%AD%EB%82%A8%EB%8F%84"
전라북도 = "https://www.daangn.com/region/%EC%A0%84%EB%9D%BC%EB%B6%81%EB%8F%84"
전라남도 = "https://www.daangn.com/region/%EC%A0%84%EB%9D%BC%EB%82%A8%EB%8F%84"
경상북도 = "https://www.daangn.com/region/%EA%B2%BD%EC%83%81%EB%B6%81%EB%8F%84"
경상남도 = "https://www.daangn.com/region/%EA%B2%BD%EC%83%81%EB%82%A8%EB%8F%84"
제주특별자치도 = "https://www.daangn.com/region/%EC%A0%9C%EC%A3%BC%ED%8A%B9%EB%B3%84%EC%9E%90%EC%B9%98%EB%8F%84"

# %%
import requests
from bs4 import BeautifulSoup

# GET 요청으로 웹 페이지 내용 가져오기
response = requests.get(제주특별자치도)
html_content = response.text

# BeautifulSoup을 사용하여 HTML 파싱
soup = BeautifulSoup(html_content, "html.parser")

# class가 "card-title"인 요소들 찾기
card_title_elements = soup.find_all(class_="card-title")

# 결과 출력 및 저장
output_file = "list.txt"
with open(output_file, "w", encoding="utf-8") as f:
    for element in card_title_elements:
        title = element.get_text(strip=True)
        print(title)
        f.write(title + "\n")

#print(f"총 {len(card_title_elements)}개의 제목을 출력 및 '{output_file}'에 저장했습니다.")
# Out:
# 고사양 게임용 컴퓨터 싸게 팝니다 배그 디아4 상옵가능!!  i5 / 3070급!
# 롯데리아 불고기 버거 세트 기프티콘 팔아요!
# 테르톤 20형 공업용 박스팬 선풍기 (2대 보유)
# 신세계상품권
# 위닉스 공기청정기 팝니다.
# 홍콩야자
# 별표주유소 주유상품권
# 캠핑장비 처분 헬리녹스 스노우피크 침낭 텐트
# 라푸마 등산배낭
# 사각 모듈 선반
# 작업대 팔아요
# 캐리어 이동식 온풍기및 에어컨
# 아이폰 14프로 128 퍼플 액정깨짐
# 레져보트 선박 4.1톤 12인승 팝니다.
# 아이폰12미니
# 티비 와사비망고 4K UHD LED TV 65인치
# 헬리녹스 택티컬 필드 터널 4.35
# 작업대 팔아요
# 빵 보관함  5천원
# 컴퓨터 본체
# 낚시용품
# 전자렌지
# 캔암레니게이드
# 늙은호박
# 기내용 캐리어 싸게 판매
# 마끼다 슬라이딩 각도 절단기
# 각파이프. 아연각관. 배달합니다
# 시마노 울테그라  c3000
# 에어포스 된장 265
# 미니 청소기 팝니다~
# 서랍장 팝니다~
# 아이폰7 팝니다
# 맥북 프로 팝니다 + 매직마우스2 일괄
# 사용감 있는 마끼다 배터리 판매합니다.
# 제습기
# 낚시대 팔아요
# 테이블
# 스탠드 행거
# 신세계상품권 지류 팝니다.
# 한샘 식탁 세트
# 삼성 노트북 팝니드
# 유아신발 130,135,140
# 냉난방기45평형 판매합니다
# 건조기 팔아요
# 리바트 리프트업 테이블(좌식테이블,쇼파테이블)
# 에어프라이어 자취 필수템
# 운동화250밀리
# 포브 등산캐리어
# 신화 테마파크 빅3
# 도서문화 상품권 판매
# 일렉기타 2016 깁슨 레스폴 트레디셔널
# 골프세트 팝니다
# 깔끔한 까사미아 시스템장 판매
# 18만짜리  스탠냄비 팔게여
# 바이크 혼다 cb125r팝니다
# 4관 콘테나
# 갤럭시 폴드5
# 미니건조기팔아요
# 흔들 1인용 한샘 쇼파
# 휴롬 착즙기
# 스타우브, 르쿠르제
# 크레모아 v600+
# 선반 팔아요~
# 선반 팝니다~
# 아디다스 삼바 그린 240mm
# 갤럭시z플립3 라벤더 특A급
# 에쉬목 2단 선반
# 아이폰14pro 128
# 노스페이스 경량점퍼
# 나이키운동화
# 회전책장
# 여성골프캐디백
# 플스4프로 1tb
# 아이폰se2 팝니다
# 벽선반 3단
# 말본모자  판매해요  (새거)
# 생선그릴
# 미소페 로퍼
# 폴로 랄프로렌 토글버튼 울코트
# 꼼대가르송 척테일러
# JBL Pulse2 블루투스 스피커
# 하루단백바 시나몬츄러스맛 단백질바
# 블루투스 스피커
# 캠핑용 220V 대용량 보조배터리
# 패딩..게스
# 노트20 판매합니다
# 엔틱가구
# HONDA ADV350  팔아요
# 테일러메이드 P7MB 아이언 팝니다
# 난로
# 믹서기 데려가세요~
# 🔹<A급> 원목 스텐 테이블 다용도책상 / 엘피 음향 카페
# 만화책 팔아요!

# %%
from konlpy.tag import Okt
from collections import Counter

# 저장된 제목을 불러오기
input_file = "list.txt"
with open(input_file, "r", encoding="utf-8") as f:
    titles = f.readlines()

# 형태소 분석기 초기화
okt = Okt()

# 모든 제목에서 명사 추출
nouns = []
for title in titles:
    nouns.extend(okt.nouns(title))

# 가장 많이 나온 상위 명사 10개 추출
top_nouns = Counter(nouns).most_common(10)

# 결과 출력
print("가장 많이 사용된 명사:")
for noun, count in top_nouns:
    print(f"{noun}: {count}회")
# Out:
# 가장 많이 사용된 명사:
# 판매: 7회
# 선반: 5회
# 아이폰: 5회
# 테이블: 5회
# 상품권: 4회
# 용: 3회
# 급: 3회
# 세트: 3회
# 캐리어: 3회
# 프로: 3회

# %%
import requests
from bs4 import BeautifulSoup

# 변수들을 딕셔너리에 저장
regions = {
    "서울특별시": "https://www.daangn.com/region/%EC%84%9C%EC%9A%B8%ED%8A%B9%EB%B3%84%EC%8B%9C",
    "부산광역시": "https://www.daangn.com/region/%EB%B6%80%EC%82%B0%EA%B4%91%EC%97%AD%EC%8B%9C",
    "대구광역시": "https://www.daangn.com/region/%EB%8C%80%EA%B5%AC%EA%B4%91%EC%97%AD%EC%8B%9C",
    "인천광역시": "https://www.daangn.com/region/%EC%9D%B8%EC%B2%9C%EA%B4%91%EC%97%AD%EC%8B%9C",
    "광주광역시": "https://www.daangn.com/region/%EA%B4%91%EC%A3%BC%EA%B4%91%EC%97%AD%EC%8B%9C",
    "대전광역시": "https://www.daangn.com/region/%EB%8C%80%EC%A0%84%EA%B4%91%EC%97%AD%EC%8B%9C",
    "울산광역시": "https://www.daangn.com/region/%EC%9A%B8%EC%82%B0%EA%B4%91%EC%97%AD%EC%8B%9C",
    "세종특별자치시": "https://www.daangn.com/region/%EC%84%B8%EC%A2%85%ED%8A%B9%EB%B3%84%EC%9E%90%EC%B9%98%EC%8B%9C",
    "경기도": "https://www.daangn.com/region/%EA%B2%BD%EA%B8%B0%EB%8F%84",
    "강원특별자치도": "https://www.daangn.com/region/%EA%B0%95%EC%9B%90%ED%8A%B9%EB%B3%84%EC%9E%90%EC%B9%98%EB%8F%84",
    "충청북도": "https://www.daangn.com/region/%EC%B6%A9%EC%B2%AD%EB%B6%81%EB%8F%84",
    "충청남도": "https://www.daangn.com/region/%EC%B6%A9%EC%B2%AD%EB%82%A8%EB%8F%84",
    "전라북도": "https://www.daangn.com/region/%EC%A0%84%EB%9D%BC%EB%B6%81%EB%8F%84",
    "전라남도": "https://www.daangn.com/region/%EC%A0%84%EB%9D%BC%EB%82%A8%EB%8F%84",
    "경상북도": "https://www.daangn.com/region/%EA%B2%BD%EC%83%81%EB%B6%81%EB%8F%84",
    "경상남도": "https://www.daangn.com/region/%EA%B2%BD%EC%83%81%EB%82%A8%EB%8F%84",
    "제주특별자치도": "https://www.daangn.com/region/%EC%A0%9C%EC%A3%BC%ED%8A%B9%EB%B3%84%EC%9E%90%EC%B9%98%EB%8F%84"
}

# 반복문을 통한 웹 크롤링 및 결과 저장
for region, url in regions.items():
    response = requests.get(url)
    html_content = response.text
    soup = BeautifulSoup(html_content, "html.parser")
    card_title_elements = soup.find_all(class_="card-title")
    output_file = f"list_{region}.txt"

    with open(output_file, "w", encoding="utf-8") as f:
        for element in card_title_elements:
            title = element.get_text(strip=True)
            print(title)
            f.write(title + "\n")
# Out:
# 아디다스 삼바
# 아이폰14프로 팔아요
# 아디다스 삼바
# 마감임박‼️)투쿨포 새상품 4000원🤭
# 다이슨 청소기 싸게 가져가세요!
# 오늘 산 베이글
# 고추가루
# 발뮤다공기청정기
# 샤넬 스니커즈 37
# 오프화이트 테이프 내로우 후드티 S
# 선물세트
# 아람 자연이랑 전집
# la갈비선물세트
# 추석선물세트 cj스페셜g호
# 발렌시아가원통백
# 버버리 10y - 간절기 경량 패딩
# 갤럭시 노트s8
# 내친구수학공룡
# 코베아큐브난로
# matin kim 마뗑킴 봄버 자켓 블랙 스티치자켓 블랙
# 아이폰 충전선 어댑터. 모두 일괄판매
# 아이폰11 프로맥스
# 컴퓨터 본체 + 모니터 팝니다
# 샤넬 니트
# 샤X 카드지갑
# 라코스테 여자 가디건 미국 s 5천원
# 롯데백화점 10만원 상품권
# 새상품 나이키 남성 기능성자켓
# 정품정리
# 아이폰12 64gb 풀박
# 에르메스 클릭아슈 블랙 골드 pm
# 새 수건
# 폴로 옥스포드셔츠 2벌
# 침대 월요일에 가져가야합니다
# 플라스틱 서랍장
# 스투시벨트
# 이케아 6단 서랍
# NIKE 나이키 정품 남성스윔팬츠
# 타이틀리스트 남자 점퍼 110
# 헬리녹스 체어원 탄색 볼핏포함
# 3단 철제 선반
# 엘지트윈스 유광점퍼
# 집 이사 때문에 가구 여러가지 정리합니다.
# 장수군 홍로 사과 추석 선물세트(13과)
# 수양사우나
# 동원참치 T21호
# 트렌비 정품프라다고프레가방
# 딥디크 플레르드뽀
# 가방
# 갤럭시 s21 판매합니다!
# 명륜진사갈비3만원권 팔아요
# 에어팟 2세대
# 220 사이즈 아이보리 파라솔 팝니다. 받침대포함
# 하만카돈 에스콰이어 미니
# 자동차 모형 벤츠
# 스팸복합1호
# 프뢰벨 말하기
# 크롬하츠 다이아반지
# 화분값만주시고 가지고 가세요
# 롯데백화점 상품권
# 레베카 막콘 11월 18일 2시 옥주현 에녹 VIP
# 조립형 PC, 데스크탑, 본체 컴퓨터 팔아욤
# 신세계상품권 12만원
# 참기름
# 쌍안경 20*50
# 남자 스킨로션 기초세트 팔아요
# 27일까지 cgv2인 영화티켓 팝콘콜라 쿠폰
# 비비안웨스트우드 진주목걸이 정품🌟
# 신세계상품권
# 버버리 머플러
# 책상 선반 웨건 액자
# 호두아몬드율무차 카누커피 양갱
# 아이룸 무선 청소기 판매합니다.
# 스피드러너 37
# 타이틀리스트 골프 스윙 점퍼
# 트레이닝복 세트
# 애플워치6 에르메스 에디션
# 위닉스 제습기
# 20인치 캐리어
# 베이스 기타와 엠프 세트
# 스팸 마일드 8호 (새제품)
# 아이폰 13프로맥스 128기가(시에라 블루)
# 남자 폴로 청셔츠
# 오징어땅콩 15봉지
# 칼하트 책가방, 백팩
# 레노버 노트북 idea pad3 15iau7
# 버버리 남아 패딩 -10y
# 샤오미 제습기 / 12L
# 컵라면 11600에 산거 너무많이사서 당근합니다
# Tapo시시티비 2대
# 캠핑장작,참나무장작 팔아용
# 레안텍 24인치 모니터팝니다
# 다이슨공기청정기
# 미우미우(정품) 급처분
# 몬테 버킷백
# 미드센츄리 테이블 판매합니다!
# 매직 북토드 여성백 마지막 가격
# 리바이스 흑청자켓 XL(105)
# 전자렌지 넘겨요
# 전자레인지 팝니다
# 키친아트 커피포트 새거 팔아요~
# 샤넬향수
# 선풍기 팝니다
# 완
# 몽클레어 구스 패딩
# 샤넬가방 정품
# 버버리 정품 목도리 일괄 판매
# 라코스테 가디건 판매
# 롯데시네마 영화관람권 9/30까지
# 갤럭시워치 6 클래식 47mm 팔아요
# 남성시계 서마(새제품)
# 갤럭시노트20울트라
# (만원) 원목거울,티테이블,서랍장
# 밀폐용기 세트
# 스탠리 텀블러 새상품
# 메디큐브 에어샷
# 페소팝니다.
# 경주 힐튼 호텔 (한글날, 조식미포함)
# 부산pcx125 21년식
# 아디다스 져지
# 스팸 6호
# 32인치 티비겸 모니터
# 상품권
# 베베드피노 가디건 90
# 메디큐브 에이지알 EMS
# 샤넬 가브리엘 백팩 스몰 내장칩 새제품
# (정품)루이비통가방
# 올리브영 만원 기프티콘 판매
# 시계 새상품
# 남성시계 요마(새제품)
# V300 7세대(웨지+아이언 풀세트) ,캐디백
# 오블 스니커즈
# 자라 와이드 팬츠
# 몽클레어 니트자켓 L
# 드릴
# 스피드랙 행거
# 낚시 장비 싸게 팝니다
# 캐리어 벽걸이에어컨 대당 5만원 총 6대
# 설화수세트.헤라폼크린져.프리메라필링겔 판매
# 소르니아 아기 옷장
# 밀폐 용기 세트
# 타요 미끄럼틀 안전한 버전 (상태 좋아요)
# 낚시경단 감성돔경단
# 모듈 투명 의자
# 아이폰 14 128g팝니다
# 엣지윌 삼탠바이미 M5 티비 스탠드 거치대
# 맥시드파이버 스니커즈 여성신발
# 로지택 G102 마우스 판매합니다.
# 타이틀리스트 골프채및가방 풀세트
# 18K 다이아팔찌
# 해바라기씨유
# 55인치고장난TV
# 숙박권 양도합니다.
# 화장지 팝니다.
# 바이크 부품(핼맷.자캣.장갑)
# MCN 여성가방 판매합니다
# 삼성냉장고 853L 내려드려요
# 메이크업포에버 다이아몬드 파우더 (No.7)
# 버팔로 캠핑 체어
# 코베아 구이바다 L
# 롯데상품권 ( 10만원 ) 팝니다~
# 이사가게 되어서 1년 안된 침대 팔아요 (매트리스 포함)
# h&m 가디건
# 갤럭시 S20 그레이 128기가
# 올리브영 5만원권
# 추석 선물세트 팝니다 - 해표예약중
# 문빈 인형 (모짜빈/눕짜빈)
# 겔럭시s22울트라
# 씨유 2만원 기프티콘
# gs25 기프티콘 2천원권 싸게 판매합니다
# (새상품)새이불
# 튀김기름정리요ᆢ
# 판매합니다
# 포트메리온 포크
# nmax 신형 머플러 ㅍㅍ
# nmax 신형 머플러 ㅍㅍ
# 폴로 랄프로렌 반집업 니트
# 갤럭시 s20 울트라 256gb 22만원
# (정품)클라터뮤젠
# 에어팟 프로1
# 김지찬 구자욱 싸인볼, 오승환 400세이브 기념구, 이원석 김태군 리유저블컵
# 분쇄기
# trek 자전거
# 태블릿 갤럭시 a8
# 순수원목 행거 선반 세트
# 동원 참치서물세트
# 라꾸라꾸온열침대팝니다.
# 스마트라이크 트램폴린
# 커플링
# 정품 에어팟2세대(유선) 판매합니다
# 밤꿀
# 1인 리클라이너(수동)
# 18k반지 루이비통 판매합니다
# (정품)피엘라벤 세트
# 18k반지 까르띠에 판매합니다
# 선물받은 멸치 팔아요
# 남자 나이키 운동화
# 엘지 드럼 세탁기  9키로
# 하이브리드 자전거
# 질스튜어트 가방
# 히니크 긴팔 니트 (아이보리, free)
# 아이폰14프로맥스 퍼플
# 타임캐시미어니트
# 신세계백화점 상품권 11만원 팝니다.
# 루이비통숄더백
# 선반판매합니다
# 삼성라이온즈 포토카드 팝니다
# 삼성라이온즈 시즌 프리권 3장 판매합니다
# 게임기 팝니다
# 삼성라이온즈 유니폼 110
# 새상품 에르메스 팝아슈 SA급 화이트 로즈골드 귀걸이
# 스팸 복합 S호 팝니다.
# 오메가 빈티지 씨마스터 오토매틱 시계
# 삼성라이온즈 신정환선수 에버랜드 유니폼
# 라디오
# 할인) MG 퍼스트건담 1년전쟁 / MG 윙건담 ew / hgce 데스티니 , 스트라이크 프리덤
# 1200*700*720 화이트 빅 테이블 책상
# 연락 주세요
# ck87황축 키보드 한성게이밍모니터{모니터는 예약중) 판매합니다
# 냉장,냉동고
# 산리오 시나모롤 다합해서 5천원!!!!
# 자전거 탑튜브가방
# 에스오일 주유권 5만권 팝니다
# 샤넬 트렌디CC 클래식 미니
# 루이비통 에스트렐라 MM - 정품
# 요기요 5만원권 2장팔아요
# 땡큐휴지30롤
# 아이폰13프로 그래파이트 256 기가
# 사이드선반
# 포트메리온
# 무게조절 덤벨 팔아요~
# 양말 선물세트
# 데이스타 125
# 조립식 철제선반 철제옷장 앵글
# 공업용선풍기 에어콘고장나서 하루써보고 내놔요. 너무쌔서 못쓰겠습니다
# 갤럭시S9 64G
# 게이밍 컴퓨터 풀셋
# 삼성라이온즈 에버랜드 유니폼 판매합니다
# 수납형 침대프레임 슈퍼싱글 사이즈 판매합니다
# 구찌 빈티지 백
# 마인 바지(모,캐시미어)
# 셀린느 트리오페 미니 크로스백
# 엔화 76000엔 팝니다.
# 노스페이스 패딩
# 18K남자 금반지 팝니다
# 2단 트롤리
# LG스마트 워치 팝니다.
# 240 플랫슈즈 4컬레 몽땅 5000🤍
# 갤럭시 폴드3 512기가 팔아요
# 콘스탄틴 어베인 17년식 픽시
# cp컴퍼니 자켓 100
# 삼성전자렌지
# 갤럭시워치5
# 버버리 티
# 트롤리 크림컬러 판매합니다.
# 삼성 드럼세탁기
# 구찌 금장 뱅글손목시계 상태A+
# 스톤아일랜드 맨투맨 팝니다
# 갤럭시 워치 액티브2
# 에어워크 고글 자전거헬멧 새제품
# 65인치 tv 팔아요
# 돈 급해서 싸게팔아요 ㅜㅠ
# 무슨 용도인지 정확하게 모르겠어요ㅠ
# 선물세트팔아요
# 미니 냉동고
# 중고 데스크탑 판매
# 노부영 베스트
# 호주오즈웨어 어그슬리퍼(아이사이즈만가능)
# 가정용 인바디 체중계
# 양파
# [팝니다] 꼼데가르송 긴팔 블랙 가디건 (100)
# 주유권
# 컴퓨터급처분합니다
# 금강제화
# 가방
# 컴퓨터 본체
# 등산스틱
# 가방
# 올리브영 상품권
# 필요하신분
# 테팔 후라이팬 4종세트
# 다양한 책 팔아요
# 가방
# 24k
# 남자 블루종 가죽자켓
# 코치가방
# i7 3770 16gb gtx660 ssd120gb 사무용 본체
# 엔진11 크릿디 건메탈 2022 픽시 급처or대차합니다!!
# 아이폰 11 프로 256, 93%
# 24K 금팔찌 팝니다.
# Giant scr 자전거 팝니다 스탠드도 드림
# 고투 자충매트더블
# 아일랜드 서랍장 800
# 냉장고 싸게 가저가세요
# 에어프라이기팝니다
# 이불차렵세트 팔아용
# 전통시장 및 상섬가 온누리 상품권
# 신세계상품권3만원 판매합니다~~~~
# 컴퓨터 본체 팝니다
# 스팸 클래식 8호 새상품
# 파워뱅크 팝니다
# 모니터
# uhd티비65인치,스마트기능
# 플스5디지털에디션
# 스텔스 드라이버
# 디올 새들 카드지갑 판매합니다
# 가방
# 갤럭시 폴드4 256gb팝니다!
# 로엠 블라우스(새상품)
# 베트남 돈  480만동  팜
# 젤네일
# 쇼케이스 냉장고팝니다
# 사물함
# 화장품 처분합니다 (베네피트 및 쿨톤 화장품 외..)
# 사물함
# 까르띠에 팔찌 18k 판매합니다
# 아이폰 12 프로맥스(pro max) 256gb
# z플립3. 팝니다
# 석쇠판스테이크판 새거
# 오늘 선물 받은 샤인머스켓 팔아요
# 컴퓨터케이스
# 스텐 다라이 팝니다
# 조이360 시그니처 카시트
# 이어폰
# 아이폰 13 프로맥스 128기가 상태 최고 에눌가능
# 애플펜슬 2세대
# 태블릿 p12 샤오신패드 2022 128g
# 노랑통닭 콜라
# 볼링공
# 에어팟 프로 2세대
# 파라핀용해기
# 디즈니골든명작 65권 전체
# 픽시구함
# 아웃백 10만원
# 백화점 상품권 팝니다(신세계)
# 한우육포세트 선물세트
# 링티+탄산수
# 배민 상품권 5만원권 2장 배달의민족 상품권
# 아스트로 문빈 진진 산하 차은우 엠제이 2023 시그
# 아기미끄럼틀이요!
# (새상품) 샤넬 향수세트 5종 팔아요
# 다이슨 헤어드라이기 정품
# 푸쉬카 판매
# 버버리 남자 남방
# 에기
# 디월트 임팩
# 젝시믹스 안다르 나이키 운동복 판매
# [새상품]DOD도플갱어 법랑 커플컵 캠핑컵
# 추석 선물세트
# 한샘 시스템장 장농 판매합니다.
# 루이비통정품  남자275
# 쏠비치 진도 10월8일 입실 1박  양도
# 에어팟 프로 1세대
# 하늘도담쌀 5키로
# 흰색선반
# 갤럭시워치4 44mm
# 디올 레이디백
# 삼성  김치냉장고 지펠 아삭 327L
# OLED TV 65인치(번인있음)
# 해표 선물세트팝니다
# 코웨이제습기
# 컴퓨터 팝니다
# 프롬유샤워핸들
# 콜롬비아 네이비 경량패딩
# 뭐하는건지는뭐르지만팔아요
# 아이패드 에어 4 풀박 급처합니다
# 분재용,화분마사
# 오토프로 플러스
# 버버리 니트(새상품)
# 디월트dcd706(거의새거)
# 발렌시아가 미니백
# 리바트 옷장 시스템장 판매합니다.
# 석류나무
# 시계
# 철제3단선반
# 갤럭시s23 512G 최상급공폰 팝니다
# 10월 2일 소노캄거제 스위트 1박 양도
# 스파게티 파스타 소스
# 갤럭시 워치3 클랴식
# 18k 반지 팝니다
# 에어팟프로 유닛
# 이거팝니다
# 동원10호
# 후드집업 팔아용
# 로지텍 버티컬마우스 (핑크색상)
# 이마트 상품권 5천원 팝니다.
# 나이키 사카이
# 명절전 판매합니다🫶
# 선풍기
# 그루비 반주기
# 프라다 사피아노 레더 미니백
# 그래픽 카드 메모리 카드
# 혼주 세트
# 두번사용했습니다
# 14k반지
# 갤럭시탭s7 128기가 셀룰러
# 프뢰벨 영아다중 팝니다.
# 갤럭시S21+팝니다
# 루이비통 루프백 판매 (가격내림)
# 팔찌18k
# 갤럭시 RTX 2060 화이트 박스 포함 최상급
# 버버리 스니커즈
# 조명 팝니다
# 갤럭시Z폴드4. 256 상태좋음.
# 생지 부츠컷
# 동원 선물세트
# 컴퓨터본체판매
# 싸게 가져가세요
# 아이폰13프로맥스 블랙 256 애케플
# 테이블
# 냉장고
# 리안크루즈 4S 양대면 절충형 유모차
# 갤럭시 z플립3 크림 256기가
# 티맥스DX530
# 맥북프로 M1 13인치 8/256GB +애플케어(24.08월)+애플마우스
# 55인치 디지털 티비 내놓습니다
# 가방
# 아이폰 아이패드 정품 충전기
# 한번 입었습니다 급전ㅜㅜ
# 김부각
# 나노훨 전동킥보드
# s20+ s20플러스 블루 256g판매
# 스톤아일랜드 패딩 21시즌 롱패딩 크링클랩스 L 다크네이비스톤아일랜드 패딩 21시즌 롱패딩 크링클랩스 L 다크네이비
# 무스너클 발리스틱
# 화물용 케리어 가방
# 스톤아일랜드 패딩 21시즌 롱패딩 크링클랩스 L 다크네이비
# 철재 행거 판매합니다
# 삼성 갤럭시 부품용 휴대폰 사망폰
# 나이키 에어로로프트
# 18만짜리 스탠냄비 팔게여
# 조이맥스 17년식
# 테이블 의자
# 아시아나 비행기 프라모델 a350 a350-900
# 구찌 크로스백
# TV 팝니다.
# LG디오스 양문 냉장고 판매합니다
# 윌슨 테니스공 소포니
# 호텔icc 객실숙박권
# 에어팟 프로 A2084
# 일본 가시는분
# 알렉산더 맥퀸
# 아이폰xs 64기가 실버 판매합니다 !
# 수세미실
# 로봇청소기
# 아이폰 13프로팝니다.
# 캠핑 화롯대
# 애플펜슬 2세대
# 아이폰11
# 킥보드부품용
# 배달의민족 5만원권 판매합니다
# 캠핑테이블세트
# (이사처분) 리바트 소파 3인용
# 서울우유 멸균팩 200ml *24
# 노스페이스자켓
# 금호리조트 숙박권 팝니다
# 대용량몬스터2리터믹서기
# 갤럭시노트10+
# 루이비통 네버풀 다미에 MM
# 의류 일괄 처분합니다
# 포카리스웨트 340ml x 20병 2박스
# 베베드피노 집업  베이비 100 사이즈, 약기모
# 디올 등 향수 3가지
# 삼성 에어컨
# 애플워치4 40mm 셀룰러모델
# 타이니모빌
# 테일러메이드 스텔스2 드라이버 팔아요.
# 쿠첸 6인용 압력 밥솥
# S20울트라 256G 팝니다
# 가와사키 발칸800
# 마크바이마크제이콥스 자동우산
# 스벅쿠폰 5만원권
# 7500F / 4070 / 32GB / 2TB 올게임 풀옵션 게이밍 컴퓨터 본체
# 갤럭시 S23 울트라 팬텀블랙 512gb (자급제) 팝니다
# 아이패드 프로3세대 11인치 64g wifi
# 온누리 상품권
# 아이폰12미니 화이트 128g 판매합니다.
# 제습기
# 아이폰12미니 64기가 블루 팝니다. 애플, 아이폰, 12mini
# 아이폰12미니 급쳐합니다
# 조자현 컨셉자전거입니다
# 자전거운동기구
# 씨투엠뉴 에이블 유모카
# 아이패드 프로 11 3세대
# 아기 버버리패딩 18m
# 루이비통 가방
# 42인치 LG TV 팝니다
# 아이폰14 급처급처급처
# 2인용 식탁의자 판매합니다
# HG 프반 풀아머건담 팝니다
# 골드바 1냥
# 캘러웨이 여성 골프웨어 가디건
# 삼성 40  인치  티비
# 벽난로장 판매합니다.
# 싱글침대
# 캔버스 토트백
# 고깃집 테이블
# 갤럭시 폴드4 256
# [샤넬 코스메틱] 샤넬 컬렉션 한정 하이라이터 까멜리아 드 플룸
# 업소용 냉장고
# 화이트 우드 블라인드
# 발렌시아가 로고 핸들 스트랩 클러치(오늘만 특가)
# 골든듀 지디러브앤하트 귀걸이 (18k)
# 로얄알버트커피잔셋트
# 나이키
# 아수스 노트북 17인치 급처
# 루이비통 포켓 오거나이저
# pcx18년식 싸게 팔아요
# (새상품)클래식자켓
# i5 6500
# 자동차 차키 리모콘 구형 부품용
# 아가짱 기저귀갈이대 재당근
# LG올레드TV55인치[55B2ENA
# 에버랜드 자유이용권 (10월 내 사용)
# 배달 콜라 팝니다
# enc 반코트
# 노트10 부품용
# 기저귀 정리대 4단
# s21플러스 256g 팝니다
# 지플립1.   256GB(블랙)가격수정
# 왕큰 참치캔 20캔 세트😙😋
# 블루베리 상토
# 아이폰12미니  128 팔아요
# 아이폰 13pro 시에라블루 자급제
# 트렉MTB
# 배 선물세트
# 폴로반팔니트
# 몇번 안쓴 대용량 샴푸 린스
# 산리오 정품 인형 일괄 판매
# 전기자전거 판매합니다
# 운동화 270~275mm 팔아요
# 시계
# 스팸100호
# 울산현대 유니폼 oem
# ☆☆☆5800x + 32gb ram 팝니다☆☆☆
# LG 2in1 에어컨
# 에어팟 프로 2세대
# 아이폰 se3
# 뉴발란스 패딩 판매
# 갤럭시 s22울트라 판매합니다
# 방갈로
# 대동경운 신형
# 면도기
# 메이커 옷들 싸게 판매합니당🩶
# 맥세이프 게임기 / 보조배테리 겸용
# 백팩 팝니다. (뉴발란스, 포니)
# 삼성 2in1 에어컨
# 프로스펙스 운동화 265
# 삼성 15.6인치 i7 쿼드코어 속도빠른 노트북 팔아요
# 폴드3  512 기가팝니다
# 몇번 안쓴 선실크샴푸 밀크바오밥 화이트머스크 트리트먼트
# 갤럭시 s22울트라 판매합니다
# 나이키 세트
# 아디다스 저지 팔아요
# 핑크맨투맨
# 아이패드 프로 2세대 10.5인치 플러스 에어팟 2세대 덤으로 증정합니다
# 작은 항아리 인테리어 소품 천원에 팝니다
# 빈폴레이디스 린넨바지 66사이즈
# 구찌 반지갑 판매합니다
# MSI GeForce RTX 2060 SUPER VENTUS OC D6 8GB
# 삼성스마트TV 벽걸이 포함
# 컴퓨터 판매합니다
# 게이밍 의자
# 나이키 바람막이
# 엔진톱. 판매
# 하프 골프백
# 자전거팝니다
# 참기름(수입)
# pu 장갑 새상품 묶음
# 에어팟 프로1
# 아디다스 바람막이
# 까사미아 라탄 협탁
# 자전거
# 리얼레더 천연 양가죽100% 여성재킷 4만원에 팝니다
# 현대오일뱅크상품권판매합니다(50만원)
# 에어팟 2세대 유선(충전기 미포함)
# 카고 조거팬츠 블랙L (S~M추천)
# 게임 패드
# 국민 상품권
# 아이폰 xr 128기가 블랙
# 캐리어 클라윈드 255L 냉장고
# 컬쳐랜드 모바일 상품권 5만원권
# 신세계 상품권 10만원 팝니다
# 배달가방 판매
# 윤석열 대통령기념시계
# 나이키 아노락
# 아이폰 SE1 스그 64GB / 배터리성능 100%
# 장난감 교구장
# 한샘 리클리이너 쇼파
# pxg밸트
# 바 테이블 의자
# 리바트
# 레스포 자전거,21단기어
# 폴로 pk티셔츠 블랙 새상품 xl
# 아이폰14프로 자급제 풀박스
# 튼튼 원목그네
# 스트라타 골프백/골프채
# 구찌반지갑
# [가격다운]  슈퍼커브125 판매 합니다 (대차는 pcx, nmax 가능)
# 로얄베일 그릇
# 룸앤티비 1세대+크롬캐스트
# 시계  빌요하신분 남자용
# 조이맥스z+
# 샤넬 CC로고 트레이너 스니커즈 (정품)
# 추석!  이게 필요할거예요
# 마젠타자전거.기어21단
# 아이패드 미니 2
# 반찬통 새재품  ♡♡  집에반찬통이많아서 처분할려고요~^^
# 조립컴 화이트 풀세트 팝니다
# 스탠리 🧡 선물용🧡 새상품
# 외목대 올리브나무/토분
# 공구
# 신세계 상품권
# 꼼데 가디건
# 참깨스틱과자 새것
# 식용유 카놀라유
# 망고 티비 55인치
# 타요 주차타워
# 어린이 킥보드
# 아이폰 xs
# 신세계상품권 18만원
# 22년형 알톤 콤보 20인치 접이식자전거 미니벨로 판매합니다.
# 쌤키즈 수납장
# 락앤락 도시락통
# 팸퍼스 기저귀 6-7단계(15kg~) 베이비드라이 120매
# 브리타 마렐라 막스트라 플러스 필터
# 아이폰 12 화이트 128기가(S급상태)
# 아이폰 SE1 스그 64GB
# 아빠차트
# 급하게 처분합니다
# 오메가 씨마스터 쿼츠
# 암웨이치약
# 갤럭시 S9+
# 베이비올 수과학
# 나이키 백팩
# 책장 선반 lp장 판매(가격내림)
# 튤립 사운드북 새상품
# (한가위 특가) 인테리어 선반, 오이엔퍼니처 크루셜 랙 001
# 바디앤솔 필라테스 양도
# 메디큐브에이지유세라딥샵
# 나이키 테크팩 조거팬츠
# 나이키 반팔
# 애플비, 블루래빗 초점책 판매합니다
# 아기 코스튬 아기 도날드 아기할로윈
# 신세계 상품권 5만원
# (새상품)샤넬 에코 미디움 토트백 블랙/화이트
# 일룸옷장
# 스팸 12호 선물세트
# 나무도마  새거와  스텐 과일바구니
# 도모디자인 아쿠아클리어 기능성패브릭소파 4인
# 아이패드 미니 4 스그 와이파이 128g 풀박스
# 나이키 드라이핏 후드집업 XL
# 한샘 싱글 침대
# 아이폰 13 미니
# 메세타 루프탑 텐트 세트 팝니다
# 골프하프백
# 테일러메이드 3번유틸
# [골프채] 테일러메이드 심1티타늄 5번 우드 판매
# 타카기 30미터 릴호스 팝니다(실사용 1회)
# new 다이슨 에어랩 롱 컴플리트 리퍼(새상품x, 재당근)
# (새상품) 5 in 1, 아이패드 노트북 탭 태블릿 받침대, 거치대, 독서대,
# 3버킷 이동식 빨래바구니 팔아요
# 파세코난로
# 이케아 스트란드몬 1인용소파
# 나이키 바람막이 집업
# 아스파라거스 나누스 화분째 팔아요
# 정관장 활기력 20ml 16병
# 캠핑용 다용도 멀티 수납가방입니다
# 버버리 정품(스카프)
# 스팸 선물세트 판매합니다.
# 다이슨 V10 앱솔루트 엑스트라 및 거치대랑 추가툴
# 팬디  골프 점퍼 M사이즈
# 아디다스 져지 블랙
# 전기그릴팝니다
# 아이폰8 (배터리 고장) 64G
# 유시몰 칫솔
# 나이키 조던 정품 275
# [정품] 셀린느 마카담 토트백 숄더백
# 카우치형쇼파
# (새제품) Lee 모자
# 스와로브스키 목걸이 판매합니다(당근 최저가)
# 육포
# 스와들업 s 오리지널(세탁만 한 새상품)
# 사랑초(예약중). 히메 몬스테라 식물
# 갤럭시 노트20 note20 kt정상해지 특A급 팝니다.(256g)
# 흑임자 일괄판매
# 폴로 자켓(급처)
# 진미 기쁨 선물셋트
# ✔새제품✔ 아미 스몰 하트 맨투맨
# 스쿠퍼니텍 드레스룸 (장농) 판매해요
# 무스너클 남자 패딩 M 중고
# 유희왕 일괄 판매합니다. 급처
# 커텐걸이 집게
# [새상품] 투썸 친환경 텀블러
# 건담 이것저것 팝니다
# 입생로랑 뷰티 파우치
# 데쌍트 백팩
# 애플워치 se 40mm 고장 부품용 풀박스
# lg전자 블루투스 스피커 ph3
# 폴로 곰돌이 반집업 니트(xs)
# 이너용 편한 플리츠 8부 바지
# 스와들업 (오리지널 이른둥이 사이즈)
# 프라다 사피아노 미디움 블랙
# 우리글 창작그림책 글끼말끼 / 몬테소리
# 다이슨 무선청소기의 헤드•툴•키트 일괄 판매(청소기 미포함)
# 네일팁 판매합니다
# 버버리키즈 베스트4y
# K리그 파니니 프리즘,보급형 카드(수원삼성)
# 꿀고구마 한입고구마
# 참치 선물셋트 2셋 일괄3만원에 팔아요
# 스팸
# 베베드피노 바람막이 팝니다
# 이케아 룬넨 25장 묶음 판매
# 와이업 휴대용 유모차
# 루이비통 카드지갑 팝니다
# 참치캔
# 스팸 카놀라유 올리고당 선물세트
# 프라다 복조리백
# 자석블럭(에드토이) 팝니다
# 아이폰 14프로맥스
# 마이크로킥보드 맥시(LED 됨)
# 싱크대
# 수납장,수납함
# 갤럭시s21핸드폰 팝니다
# 신세계 이마트 상품권 2장
# 겔럭시 S10 5G 256G 팝니다
# 숲소리 원목블럭 66P
# 삼성에어컨 10만에 드려요
# 매장 집기/잡다한 것들 판매 합니다. 많은 문의 주세요.
# 미니로디니 9298 외 티셔츠 4종 일괄
# 위닉스뽀송 제습기 17L
# 해바라기버너
# 노트 10+
# 고야드 가방
# 아이폰 13 스타라이트
# 냉장고 팔아요
# 거울 미니선반 일괄 판매합니다
# 입생로랑 스몰 클러치 팝니다
# 아이폰 13 화이트 / 배터리 성능 83%/128GB
# 꼼데 가디건
# 티파니앤코 리턴투
# 샤넬램스킨체인볼
# 안방그릴
# 베베드피노 테디베어 점퍼 100
# 테일러 스파이더ex 퍼터 팝니다.
# 아베크롬비
# 천막
# 플립4 판매
# NMAX싸게 팔아요
# 금팔찌 팝니다
# 사무용 컴퓨터 판매합니다!
# 상태좋은 의자 일괄로 팝니다.
# 고사양게이밍노트북 싸게 팝니다~
# 이케아 트롤리
# 프뢰벨 영아다중
# A325 64GB 퍼플
# 신세계상품권 10만원권 (+1만원은 그냥 드려요)
# 광명 게이밍의자 팔아요
# 신세계상품권 2장 팝니다^^(쿨거 시 네고)
# 필리핀 만페소 네이버환율보다 싸게 팝니다
# 까사미아 서랍장
# LG디오스 세탁기건조기 세트
# 공기계 가져가세요
# 4단수납선반(철제,화이트)
# 갤럭시 Z플립3 자급제 휴대폰
# 스팸+리챔 판매합니다
# 10/2~3 양평 캠핑장 양도합니다.
# 아이폰11 (128GB) 화이트 팝니다 상태 좋아요
# 삼성 2016 에어컨 판매
# 로드자전거
# 전자렌지 팝니다
# 차렵 이불(새상품)
# 여친이랑 헤어져서 팝니다
# 식용유
# 젝시오 여성 5번 우드
# 폴로랄프로렌 꽈배기니트(XXL)
# 폴로가디건 라지
# 음료수 냉장고 2대
# 샤오미 펫드라이룸
# 루어낚시세트 판매합니다
# 오데마피게
# 콘스탄틴 어베인 2016 픽시 대차
# k2 트레킹화~등산화
# LG휘센 에어컨 2in1   FQ17V9WWCN
# 폴더매트
# 슬라이딩각도기
# 차이팟 에어팟 프로2
# 랑방등 숄더백 모음
# 아이폰14프로맥스
# 베베드피노 상.하의 100 사이즈
# 급처)홈바 식탁 의자 판매합니다.
# 리고 땅콩버터
# 분리수거함 5000원
# Iphone 6splus 64gb
# 아이폰12프로128기가
# 갤럭시s10 5g 256기가
# 아이팟나노1,중소기업 mp3
# 갤럭시 s21 팔아요!!(마지막가격내림)
# 연장통
# 전자렌지 넘겨요
# 철원오대쌀 10kg  기준 입니다
# 갤럭시노트20
# 후아유 양털 후드집업
# 페소팝니다
# 스팸6호
# 컨테이너 하우스
# 볼빅 모자
# MCM 가방
# 고구마판매
# 모니터 겸 TV
# 아이폰 6 판매합니다!!
# 신세계 이마트 지류 상품권 2만원권 판매
# [ 정품 ] 구찌 소호가죽 디스코백
# 현관.도어록
# 미드센츄리 유리테이블, 가죽소파 팝니다
# 구찌 가방 판매합니다 (정가 295만원)
# 월광보합 게임기
# 6인용 식탁과 의자
# LG WING
# 블루래빗 아기책 전권
# 자연진리 명작 배 8구 세트
# 탁상드릴
# 보스턴백
# 가격내림680000
# 크록스 새거
# 소장 휴대용 게임기들 처분해봅니다
# 나무 선반 판매합니다 !
# 힐티 충전드릴 콤보
# 밤 팝니다.
# 윤석열 대통령 시계 (남성용)
# 아디다스 풋살화 270(265)
# 청정원  올리유 NH1호
# 계양예초기
# 폴드5 크림판매
# 골전도이어폰 에프터샥 650 판매합니다
# 디올 카드지갑
# 돌잡이 수학 돌잡이 한글 첫걸음놀이수학
# 카놀라유 500mL
# 아이폰13 그린 128기가 자급제
# 꼬꼬맘
# 여자 숏패딩
# 카우치팔아요
# 나이키 농구화 gt cut 2
# 방탄소년단 굿즈
# 꼬꼬맘 박스풀 판매합니다.
# 아이폰 14프로 128 풀박스 팝니다
# 범킨스 긴팔 턱받이(이유식용)
# 레몽카디
# 아이폰 13 미니 블루 256gb  뒷면 액정 파손
# 토종꿀 1.2kg
# 비앙키 E아리아 전기로드 전기자전거 판매합니다
# 철제 방문 가드 팝니다!
# 독일 햄튼 칼세트 식도세트
# 동원참치
# 좆되는 전동킥보드
# 아이폰11프로 256기가
# 스매쉬 전동드릴
# 원목 테이블, 의자 팝니다
# 믹서기 싸게 처분합니다!
# 에어팟2세대
# 신세계 상품권 20만원 일괄판매
# 아이패드 프로 3 11인치 64GB
# 가히 멀티밤
# 캠핑용품 팝니다~
# 리바트 슬라이딩 책장
# 에어팟 프로 1
# 베이프 후드집업
# 원목 수납장 팝니다.
# 나이키 운동화 240
# 골프가방새거
# S22 울트라 판매합니다
# 아이패드
# 롤렉스
# LG 냉장고 870L 2도어 팝니다.
# 3단 수납 선반 판매
# 스피드랙
# 이마트,신세계상품권 팔아요~
# 수저세트 팔아요
# 레모나 70포
# 아이폰13미니 스타라이트 자급제 256 A급 팝니다
# 가전제품 판매합니다.
# 유리창 시트지
# 캠핑 화목난로
# 구찌 크로스백
# 에어팟 프로 1세대 팝니다
# 동원참치
# 원목 곡목 체어 팝니다
# 전둥킥보드 팝니다
# 아이폰 12미니 팔아요 ~
# 접이식 세탁기
# 수저 세트 팔아요
# 겔럭시탭
# 동원 참치
# 가스렌지
# 정관장 활기력 선물용 새상품 팝니다
# 컵라면
# 풍년  압력솥  9리터12인분
# 갤럭시 노트9 128GB 화이트 팝니다.
# 아이폰SE2 128GB 판매해요
# 파라핀  치료기 np-888
# 피에스타 원목 주방놀이 스칸디
# 판넬 농막
# 피셔프라이스 러닝홈 국민문짝
# SK주유권 판매
# 스텐드 핸드폰 거치대 팔아요
# 베네베네 세트 18m (촬영용 추천)
# 도라지배즙국내산100%
# 코드그라피 숏후드 패딩
# 노스페이스 트레이닝바지
# 에어팟 프로 2세대
# 캠핑용품 버너
# 탁구화(260mm) 255~265 사용가
# 신세계/이마트 상품권(10,000원) 팝니다.
# 폴로셔츠 정품
# 무선전화기
# 일회용 숟가락
# 캠핑박스
# 네파
# 김 치 10키로~~
# 릴낚시 세트. 가방은 서비스
# 엘지 텔레비젼
# 파이프 중고자재
# 샤넬 미니하트백 새상품 더스트구성
# 프라다 복조리백 새상품
# 샤넬 골든볼 미니 새상품 영수증포함
# 샌드위치판넬 팝니다.
# 밍크슬리퍼 핑크,블랙 235 새상품
# 생리대 모두 단돈 5천원
# 스팸 마일드8호
# (픽시) 룩 464 팝니다
# 아이팟 터치2
# 책상 의자 세트
# 아이패드 11인치 케이스+블루투스 키보드
# 향나무 가져가실 분
# 업소용 에어컨 판매
# 햅쌀 10키로 4포 팝니다.
# 소각드럼통
# 발렌시아가 후드집업
# 하우스파이프
# 삼성 공기청정기+필터리필 팝니다
# 냉장고 팔아요
# BSW독일 대용량전기후라이팬 새제품 ( 박스없음)
# 들통
# 타이니러브  모빌 흑백홀더+컬러홀더
# 아이폰 12 미니
# 발바사지기 팔아요
# 아이폰13프로 128기가
# 아이폰14프로 128GB 실버 자급제 판매합니다.
# 크린백
# 투썸(15700원 정가)
# 기타 받침대
# 샴푸
# 아벤트 보틀워머
# 13900ks 4090 현재 끝판왕 컴퓨터 판매합니다.
# 탁자 파라솔
# 고가구
# 컴퓨터 의자
# 은 체인팔찌
# 끌로에 신상 우디백 새상품
# 세탁기, 건조기, 거치대 판매
# 베베드피노(100)
# 급하게 내놔요. 금고
# 본체
# 루비이통 페이보릿 가방팔아요
# s22울트라
# 예일 기모 조거 셋업 트레이닝
# 가마솥 솥단지
# 리바트 식탁판매합니다
# 콘스탄틴 버나드 픽시 자전거
# 남아 더예한복
# 행주
# 스패로우 그랜드 매트
# 딥스.홈짐
# 디월트 송풍기 판매합니다
# 애플워치Se 40mm 급처 합니다
# 룸앤티비2세대 팝니다.
# 플스 프로 ps4 pro 팝니다.
# 디스커버리 후드 자켓
# 분리수거함
# 사실분....
# 명품 팝니다
# (가격다운)갤럭시S21 울트라 512 램16 풀박스 팔아용~
# 애플망고 첫 수확
# 베이비클로 이유식 턱받이(새제품 포함)
# 어메이즈핏 GTR4 한달사용 팝니다
# 블루독 유아점퍼 90
# 아이폰 14프로맥스 256기가 실버색상
# 삼성 에어컨 판매합니다.
# 카베자 17년식 픽시 판매
# 베베드피노나시/130
# 렌지자이 주방선반
# 올리브영 기프트카드 5만원
# 제빵기.휴롬.커피.오쿠
# 갤럭시Z폴드5  256기가 크림
# 식용유
# 그라인더 마끼다
# 바이마르 멀티 채반 믹싱볼세트
# 금팔찌 20돈팝니다
# LG 노트북 가방(새상품) 서류가방
# 전기장판
# 싸게팔아요
# 의료침대 전동침대
# 벨 냉장고
# 타이니모빌
# 오프화이트 후드집업 급처합니다
# LG 빔프로젝트
# TV
# 노트20 Ultra SSS급
# 동원참치 프리미엄 10호
# 보관만한 답례품수건 정리합니다
# A4용지 4권(2000매)
# 급처 원가 5만 소프시스 코너선반 화이트 디자인
# 프라다 정품지갑
# 책장
# 삼성 휴대폰 갤럭시 퀀텀2  팝니다.
# 나이키 후드바람막이아노락
# 아이폰 14
# 해바라기씨유
# 냉장고
# 급처 한샘 북선반 10단 원가 9만 5천
# asus gtx1650 super 팝니다
# 가디건(105)
# 서랍형 사이드 침대협탁 상태매우좋음
# 트랙터 35마력
# 캉골 미니백
# 구찌이미가방
# 폴로니트
# 스투시 정품 후드티 L 정가 20만원
# 30만원대 주고 구매한 테이블 의자 싸게 넘겨요
# 테일러메이드 골프가방 캐디백
# 캠핑폴딩박스 풀세트
# 주방수납장
# 인력거 (자전거)
# 트랙터35마력
# 여수숙소(10/1-10/2)
# 다이슨 드라이기
# 빈티지 티테이블
# 책장
# 사각 물탱크
# 나이키 골프화
# 아이폰 14 판매
# mlb바막
# 미쏘 패딩자켓
# 엘지 울트라 노트북 판매요
# 성인용텐트
# 갤럭시 워치5케이스
# 18만짜리 스탠냄비 팔게여
# 아이패드 프로 5세대 12.9 wifi-128GB 팝니다
# 버즈 플러스
# 리안 아기침대
# 캘러웨이 보스턴백 판매해요
# z폴드5.256gb.s급 팔아봅니다
# 찰리푸스 내한 p석 양도
# 테일러메이드 P790 아이언 세트(4~P)
# 로드 자전거
# 전자렌지 팝니다
# PXG 골프조끼 L 사이즈
# 놀이터 팝니다
# 말본골프모자
# 아기 후부스터
# 냉동 저온창고
# 2톤 마이티 저상
# 갤럭시 노트20
# 주방수전
# 나이키 조거팬츠 s
# 설곤약
# 손수레
# 돌김(한박스)
# MLB 비니
# 아이패드4 5만원에 가져가세요
# 캠핑 접이식 의자, 워터저그 받침대 판매합니다.
# 3인용 쇼파 팝니다
# 판넬
# 아이폰12 128 판매합니다
# 나주 배
# 순천만 국가정원박람회 티켓
# 밤줍기 합니다.
# 스탠바이미 팝니다
# 교동 선지해장국4 버섯들깨탕2
# S23 크림 256gb
# 식이섬유가 포함된 프락토올리고당 판매
# 아이폰13프로맥스 블랙 256G S급
# 항아리
# 구찌 숄더백 미디움
# s21
# 가방구경하세용~~
# 삼성 TV
# 홈짐 세트 팝니다. 별도판매 가능(중량봉, 원판, 케이블, 벤치, 매트, 거울, 덤벨 등)
# 롯데 상품권
# 콜라 판매합니다!
# LG 휘센 2in1 에어컨 판매합니다
# 동원선물세트
# 자전거
# 프라다 사피아노 크로스백 라지
# 놔둘곳이 없어 딩근 합니다
# 버버리 신발팔아요
# 캠핑의자 2EA
# LG제습기 10리터 LD-105DR 팝니다.
# 22년식크루심300알파 팝니딘
# 비젼냄비 팔아요.
# 롯데 상품권 10만원
# 행거팔아요
# 콜라보 트루컬러 자동차광 용접면 팝니다
# 세탁기
# 에어팟 프로 판매합니다! (1세대)
# 숲소리 자석 블럭 원목블럭 돌아기장난감
# 매트리스 깔판
# 흑청 나팔컷 청바지
# 아이폰12프로 258기가
# 갤럭시Z폴드4 512G 베이지
# 내열냄비
# 골프 드라이버 나이키 SQ sumo2
# 밀워키 배터리 팝니다
# 에어팟 프로1
# 엔진톱입니다
# 02굴삭기, 트렉터 판매합니다
# 이케아 아기의자
# 커피묶음
# 게이밍 컴퓨터 라이젠 5600x, 3060, 모니터 포함 판매합니다
# 철판 판매합니다
# 겨울용 침낭팔아요
# 쿠첸 6인용 밥솥
# 쵸크형))18k 목걸이
# 4단선반
# 진공청소기
# 화로대 판매합니다.
# 설록차선물셋트
# 책상
# 메이드복 팝니다
# 스팸 200g 10캔
# 갤럭시 노트 20 울트라
# 스팸 팔아요
# 차렵이불~~~
# 선물세트 팔아요
# 롯데상품권 2500만원
# 정말 깨끗한 드론 팔아요
# 갤럭시 워치4 (40mm)팔아요
# 아이폰14 프로맥스 256 실버 팝니다
# 200달러 판매합니다.(1360)
# 아이폰11프로 64
# 베베드피노 바지 3종 새옷
# 에어팟 맥스
# 유아자동차 아기자동차 벤츠자동차
# 흙표 온돌흙침대 싱글사이즈
# 필요 없어서 판매합니다
# 콘테이너 2.4×2.3'4
# 롯데상품권 10만
# 에어팟 프로 판매
# 뉴발란스530SG
# 갤럭시탭 10.4인치 sm-t536 팝니다 개당 가격입니다
# 갤럴시 노트20 울트라 팝니다
# LG 디오스 김치냉장고 판매합니다.
# 버섯 이름
# 차량용냉장고
# 자동차청소기
# 스팸12호
# 골프채# 핑 G410 아이언 풀셋
# 신세계상품권 판매합니다
# 냉장고 팝니다
# 데상트 후드집업
# 조이맥스 125
# 오버더바이크
# 갤럭시 노트9
# 발렌시아 반팔
# 하야시에기
# 유진 아이디 카드
# 믹서기
# 18k 팔찌팝니다
# 조던 1 x 트래비스 스캇 x 프라그먼트 레트로 로우 OG SP 밀리터리 블루
# 정관장 홍삼입니다
# 테이블 쇼파세트
# 삼성 336L냉장고
# 게이밍의자
# 하체 조지세요
# 타보플렉스2 휴대용유모차 판매합니다
# 신세계상품권10만
# 갤럭시 s21
# 디스커버리가방
# 신일선풍기
# 참기름
# 벌꿀 판매합니다
# 멸치팔아요~
# 새상품)     선물세트
# 롯데백화점 상품권 13만원
# 부린 강염버너 판매합니다.
# 칫솔
# 42인치엘지티비
# 셀린느 백
# 손목시계
# 갤럭시 노트10 플러스 512
# 신세계백화점 상품권
# 겔럭시텝 s7+ 256GB
# 추석선물
# 스팸복합1호 팝니다
# 에어컨 팔아요
# 18K 도금 대나무 목걸이 판매합니다
# 서울우유
# 아이폰 6s
# 4인 소파 팝니다
# 앵글 선반
# 포켓몬카드
# 갤럭시23울트라 512
# 난로 판매합니다
# 갤럭시워치4 골프에디션
# 아이폰13프로맥스
# 아이스박스
# 핑 패딩조끼
# 갤럭시23울트라 512
# PXG투어 캐디백
# 디올 향수 미니어처
# 이케아 암체어
# 유아 웨건
# 홍삼 선물세트
# 에스웍스 에이토스 로드자전거
# 샤인4kg
# iPhone 13 Pro
# 오롯이 재래김 선물세트
# 산청엑스포 어른티켓
# 머리집게 일괄
# 두세살 아기옷 여자아기옷 90사이즈 정도
# 에어팟 프로 1세대 본체 급처합니다
# 이케아 조명
# 아이폰13프로 골드로 14프로 교환하고싶습니자
# 켈러웨이 골프 바지
# 루이비통 가방
# 비누
# 아기옷 4~5세
# 전남친목걸이(18k)
# 그냥 싸게팔아요..
# 게이밍 PC 컴퓨터 본체 팝니다.
# 캠핑 알루미늄 롤테이블 + 가죽 테이블 보
# 아이폰 12미니 128gb
# 마늘 양파백
# 자전거
# 프라다 버킷백
# 새상품급 애플워치 se 40
# 타파 후라이팬
# 매트 판매합니다
# 코펠
# 뉴발란스키즈 트레이닝 셋트 130
# 골프백 팝니다
# 레즈보트판매
# 수심체크릴 로드 팝니다
# 2단서랍장 (상태ss급)
# 간단하게  선물하실분께 ~~
# 페도라 디럭스 유모차
# 나이키 조던바람막이
# 고사양 게임용 컴퓨터 싸게 팝니다 배그 디아4 상옵가능!!  i5 / 3070급!
# 롯데리아 불고기 버거 세트 기프티콘 팔아요!
# 테르톤 20형 공업용 박스팬 선풍기 (2대 보유)
# 신세계상품권
# 위닉스 공기청정기 팝니다.
# 홍콩야자
# 별표주유소 주유상품권
# 캠핑장비 처분 헬리녹스 스노우피크 침낭 텐트
# 라푸마 등산배낭
# 사각 모듈 선반
# 작업대 팔아요
# 캐리어 이동식 온풍기및 에어컨
# 아이폰 14프로 128 퍼플 액정깨짐
# 레져보트 선박 4.1톤 12인승 팝니다.
# 아이폰12미니
# 티비 와사비망고 4K UHD LED TV 65인치
# 헬리녹스 택티컬 필드 터널 4.35
# 작업대 팔아요
# 빵 보관함  5천원
# 컴퓨터 본체
# 낚시용품
# 전자렌지
# 캔암레니게이드
# 늙은호박
# 기내용 캐리어 싸게 판매
# 마끼다 슬라이딩 각도 절단기
# 각파이프. 아연각관. 배달합니다
# 시마노 울테그라  c3000
# 에어포스 된장 265
# 미니 청소기 팝니다~
# 서랍장 팝니다~
# 아이폰7 팝니다
# 맥북 프로 팝니다 + 매직마우스2 일괄
# 사용감 있는 마끼다 배터리 판매합니다.
# 제습기
# 낚시대 팔아요
# 테이블
# 스탠드 행거
# 신세계상품권 지류 팝니다.
# 한샘 식탁 세트
# 삼성 노트북 팝니드
# 유아신발 130,135,140
# 냉난방기45평형 판매합니다
# 건조기 팔아요
# 리바트 리프트업 테이블(좌식테이블,쇼파테이블)
# 에어프라이어 자취 필수템
# 운동화250밀리
# 포브 등산캐리어
# 신화 테마파크 빅3
# 도서문화 상품권 판매
# 일렉기타 2016 깁슨 레스폴 트레디셔널
# 골프세트 팝니다
# 깔끔한 까사미아 시스템장 판매
# 18만짜리  스탠냄비 팔게여
# 바이크 혼다 cb125r팝니다
# 4관 콘테나
# 갤럭시 폴드5
# 미니건조기팔아요
# 흔들 1인용 한샘 쇼파
# 휴롬 착즙기
# 스타우브, 르쿠르제
# 크레모아 v600+
# 선반 팔아요~
# 선반 팝니다~
# 아디다스 삼바 그린 240mm
# 갤럭시z플립3 라벤더 특A급
# 에쉬목 2단 선반
# 아이폰14pro 128
# 노스페이스 경량점퍼
# 나이키운동화
# 회전책장
# 여성골프캐디백
# 플스4프로 1tb
# 아이폰se2 팝니다
# 벽선반 3단
# 말본모자  판매해요  (새거)
# 생선그릴
# 미소페 로퍼
# 폴로 랄프로렌 토글버튼 울코트
# 꼼대가르송 척테일러
# JBL Pulse2 블루투스 스피커
# 하루단백바 시나몬츄러스맛 단백질바
# 블루투스 스피커
# 캠핑용 220V 대용량 보조배터리
# 패딩..게스
# 노트20 판매합니다
# 엔틱가구
# HONDA ADV350  팔아요
# 테일러메이드 P7MB 아이언 팝니다
# 난로
# 믹서기 데려가세요~
# 🔹<A급> 원목 스텐 테이블 다용도책상 / 엘피 음향 카페
# 만화책 팔아요!

# %%
from konlpy.tag import Okt
from collections import Counter

# 저장된 제목 파일 목록
region_files = [f"list_{region}.txt" for region in regions.keys()]

# 형태소 분석기 초기화
okt = Okt()

# 모든 제목에서 명사 추출
all_nouns = []

for region_file in region_files:
    with open(region_file, "r", encoding="utf-8") as f:
        titles = f.readlines()

    region_nouns = []

    for title in titles:
        region_nouns.extend(okt.nouns(title))

    all_nouns.extend(region_nouns)

# 불용어 설정
stop_words = ['판매', '기', '용', '인치', '상품', '갤럭시', '삼성', '프로', '미니', '세트', '세대', '단', '정리', '정품', '사이즈', '애플', '블랙', '화이트', '일괄', '급', '급처', '제품', '나이키', '신세계', '선물', '울트라', '아기', '밍', '게이', '맥스', '호']

# 불용어 제외하고 명사 카운트
filtered_nouns = [noun for noun in all_nouns if noun not in stop_words]
top_nouns = Counter(filtered_nouns).most_common(10)

# 결과 출력
print("가장 많이 사용된 명사:\n")
for noun, count in top_nouns:
    print(f"{noun}: {count}회")
# Out:
# 가장 많이 사용된 명사:
#
# 아이폰: 66회
# 상품권: 41회
# 가방: 30회
# 선반: 24회
# 에어팟: 21회
# 테이블: 20회
# 컴퓨터: 18회
# 스팸: 17회
# 골프: 17회
# 의자: 17회
